# %%
# %%capture
import os
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer, util
import json
import spacy
from functools import lru_cache
import torch

# Matching Algorithm Required Functions
from utils.semantic_similarity import nlp_similarity_cached 
from utils.semantic_similarity import sentence_model 
from utils.mandatory_skill_score import calculate_mandatory_skill_scores
from utils.preferred_skill_score import calculate_preferred_skill_scores
from utils.responsibilities_match_score import calculate_responsibilities_scores
from utils.mandatory_education_score import calculate_mandatory_education_scores
from utils.preferred_education_score import calculate_preferred_education_scores
from utils.mandatory_credentials_score import calculate_mandatory_credentials_scores
from utils.preferred_credentials_score import calculate_preferred_credentials_scores
from utils.mandatory_background_score import calculate_mandatory_background_scores
from utils.preferred_background_score import calculate_preferred_background_scores
from utils.merge_scores import merge_scores_by_job_id

### Data Ingestion (To be Removed in Production)
current_wd = os.getcwd()

def safe_json_loads(val):
    try:
        return json.loads(val)
    except json.JSONDecodeError:
        print(f"Error parsing JSON: {val}")
        return None

job_desc_data = pd.read_excel(os.path.join(current_wd, "data", "sample_des_extractions_test_final_3.25.25.xlsx"))
resume_data = pd.read_excel(os.path.join(current_wd, "data", "sample_res_extractions_final_3.26.25.xlsx"))

job_desc_data["job_desc_parsed"] = job_desc_data["extracted"].apply(safe_json_loads)
resume_data["resume_parsed"] = resume_data["extracted"].apply(safe_json_loads)

job_desc_json = job_desc_data['job_desc_parsed']
resume_json = resume_data['resume_parsed']

def append_job_id_to_job_desc(row):
    job_id = row['id']
    job_desc = row['job_desc_parsed']

    if job_desc is None:
        return None
    
    if isinstance(job_desc, str):
        job_desc = safe_json_loads(job_desc)
        if job_desc is None:
            return None
    
    job_desc['job_id'] = job_id
    return job_desc

job_desc_data['job_desc_json'] = job_desc_data.apply(append_job_id_to_job_desc, axis=1)

def extract_all_strings_from_json(j):
    """
    Recursively extracts all non-empty strings from a JSON-like object (dict or list).
    """
    result = []
    if isinstance(j, dict):
        for v in j.values():
            result.extend(extract_all_strings_from_json(v))
    elif isinstance(j, list):
        for item in j:
            if isinstance(item, str):
                s = item.strip()
                if s:
                    result.append(s)
            else:
                result.extend(extract_all_strings_from_json(item))
    return result

def precompute_embeddings_for_json_list(json_list, batch_size=64):
    """
    Iterates over a list (or Series) of JSON objects, extracts all non-empty strings
    from each JSON, computes embeddings for all unique strings in batches, and returns
    a dictionary mapping each unique string to its embedding.
    
    Parameters:
      json_list (iterable): A list (or Series) of JSON objects (dicts).
      batch_size (int): Batch size for encoding.
      
    Returns:
      dict: A mapping from string to its embedding.
    """
    all_strings = set()
    for j in json_list:
        if j is None:
            continue
        strings = extract_all_strings_from_json(j)
        all_strings.update(strings)
    
    all_strings = list(all_strings)
    if all_strings:
        embeddings = sentence_model.encode(all_strings, batch_size=batch_size, convert_to_tensor=False)
    else:
        embeddings = np.zeros((0, sentence_model.get_sentence_embedding_dimension()))
    
    string_to_emb = {s: emb for s, emb in zip(all_strings, embeddings)}
    return string_to_emb

embeddings = precompute_embeddings_for_json_list(job_desc_json, batch_size=64)

#### End of Data Ingestion (To be Removed in Production)

# %%
canidate_resume_JSON  = resume_json[7]
job_desc_json_lst = job_desc_json[0:100]

print(f"Total Length of Sample: {len(job_desc_json_lst)}")

# Run Match Score 
# Stage 1: 
# 1.1. Calculate credentials scores
mandatory_credentials_scores = calculate_mandatory_credentials_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)
preferred_credentials_scores = calculate_preferred_credentials_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)

# 1.2. Calculate education scores
mandatory_education_scores = calculate_mandatory_education_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)
preferred_education_scores = calculate_preferred_education_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)

# 1.3. Calculate background scores
mandatory_background_scores = calculate_mandatory_background_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)
preferred_background_scores = calculate_preferred_background_scores(job_json_list=job_desc_json_lst, resume_json=canidate_resume_JSON)

# Stage 1.5: Filter after the first stage
stage1_scores = merge_scores_by_job_id(mandatory_background_scores, 
                                      preferred_background_scores, 
                                      mandatory_education_scores,
                                      preferred_education_scores,
                                      mandatory_credentials_scores,
                                      preferred_credentials_scores,
                                      filter = True,
                                      threshold= 0.5
                                      ) 

stage_job_desc_json_lst = [job for job in job_desc_json_lst if job.get('job_id') in set(stage_scores.keys())]

print(f"Total Length of Sample after Stage 1: {len(stage_job_desc_json_lst)}")

# Stage 2:
# 2.1. Calculate responsibilities scores
mandatory_responsibilities_scores = calculate_responsibilities_scores(job_json_list=stage_job_desc_json_lst, resume_json=canidate_resume_JSON)

# 2.2. Calculate skills scores
mandatory_skills_scores = calculate_mandatory_skill_scores(job_json_list=stage_job_desc_json_lst, resume_json=canidate_resume_JSON)
preferred_skills_scores = calculate_preferred_skill_scores(job_json_list=stage_job_desc_json_lst, resume_json=canidate_resume_JSON)

# Stage 2.5: Filter after the second stage
stage2_scores = merge_scores_by_job_id(stage1_scores,
                                    mandatory_responsibilities_scores, 
                                      mandatory_skills_scores, 
                                      preferred_skills_scores,
                                      filter = True,
                                      threshold= 0.5
                                      )
# Out:
# Total Length of Sample: 100
# Total Length of Sample after Stage 1: 34

# %%
final_scores
# Out:
# {'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'mandatory_background_score': 0.7051542997360233,
#   'mandatory_industry_score': 0.6039740244547528,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.7307955225308739,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 1.0,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'mandatory_background_score': 0.7453494866689048,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_background_score': 0.6464272340138755,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': 0.6998847524325055,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 1.0,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'bb464343-964a-4eb5-851d-a7cc5753625e': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '3e3466a5-1799-4648-883d-ab43f1278a53': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': 0.7070150905185276,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'c540dda2-7f78-4584-9a93-0d4c5ee2981b': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '3aa02d0d-814b-4acc-ab15-06c897ebdec8': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '7e8c1297-5fb7-4431-bfd0-ff76a071a24b': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '3d6abfd2-971f-4279-bd5c-e2608afb27b8': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'c50cd8cd-60d1-48a7-8db8-7e828210c020': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '18df64e2-17f0-45b0-8759-ba1b89fad7dd': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '27b81e47-a357-4bc9-bf00-3a854b2c03f1': {'mandatory_background_score': 0.6571214993794761,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': 0.7442596488528782,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '2d321fc0-5661-4154-a156-b49b749b0d0f': {'mandatory_background_score': 0.612178405125936,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'a7df6bed-41c2-4ccd-a3a1-d0bfb90adf5e': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '06ba6c67-c4eb-4358-aa2a-64dc8d186198': {'mandatory_background_score': 0.665874242782593,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': 0.7436439990997316,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '794dda95-c86e-4575-90dd-6d5fe9b34268': {'mandatory_background_score': 1.0,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 1.0,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '181b9a3d-71ca-420e-8ea8-08b348ad69f2': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '639fb093-26a8-4745-9656-ee93f3b79f19': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '65ad643c-f389-494e-aaba-210e41917b8d': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '53acdd0a-467a-413e-9486-42a2b86b5c66': {'mandatory_background_score': 1.0,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  '2b2477c7-fafb-411f-b890-11cbb24d02e0': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': None,
#   'preferred_education_score': None,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None},
#  'a45a153b-9da6-4c44-9390-b46a38181eca': {'mandatory_background_score': None,
#   'mandatory_industry_score': None,
#   'preferred_background_score': None,
#   'preferred_industry_score': None,
#   'mandatory_education_score': 0.9999996026357016,
#   'preferred_education_score': 0.7070150905185276,
#   'mandatory_credentials_score': None,
#   'preferred_credentials_score': None}}

# %%
job_desc_json[0]
# Out:
# {'details': {'wage': [{'max': 120000,
#     'min': 100000,
#     'pay_type': 'Salary',
#     'wage_city': [],
#     'wage_state': []}],
#   'benefits': {'fsa': False,
#    'hsa': False,
#    'bonus': False,
#    'other': [],
#    'dental': False,
#    'equity': False,
#    'vision': False,
#    'medical': False,
#    '401k_match': False,
#    'mental_health': False,
#    'unlimited_pto': False,
#    'tuition_reimbursement': False},
#   'location': [{'city': '', 'state': '', 'country': 'Remote'}],
#   'job_title': ['Sr. Ab Initio Developer'],
#   'tax_terms': ['Direct-hire'],
#   'wfh_policy': ['Remote'],
#   'company_name': [],
#   'company_stage': [],
#   'work_schedule': [],
#   'job_title_base': ['Senior Ab Initio Developer'],
#   'employment_type': ['Full-time'],
#   'travel_required': {'required': False, 'hours_weekly': 0},
#   'company_industry': [],
#   'experience_level': ['Senior'],
#   'work_authorization': []},
#  'mandatory': {'education': [{'field_of_study': ['Computer Science',
#      'Related'],
#     'education_level': ["Bachelor's"]}],
#   'credentials': [],
#   'hard_skills': [{'skill': [['UNIX']], 'minyears': [6]},
#    {'skill': [['Ab Initio Graphical Development Environment']],
#     'minyears': [6]},
#    {'skill': [['Ab Initio Meta Data Hub']], 'minyears': [6]},
#    {'skill': [['Ab Initio EMEB']], 'minyears': [6]},
#    {'skill': [['Ab Initio Continuous Flows developing web services']],
#     'minyears': [0]},
#    {'skill': [['Control M Scheduler']], 'minyears': [0]},
#    {'skill': [['ETL tools']], 'minyears': [0]},
#    {'skill': [['Ab Initio tools'], ['Query>IT'], ['MDH'], ['BRE']],
#     'minyears': [0]},
#    {'skill': [['SDLC']], 'minyears': [0]},
#    {'skill': [['Draw out high-level and detailed designs']], 'minyears': [0]},
#    {'skill': [['represent them as flow diagrams']], 'minyears': [0]},
#    {'skill': [['Translate business requirements']], 'minyears': [0]},
#    {'skill': [['functional and technical specifications']], 'minyears': [0]},
#    {'skill': [['Design end-to-end data warehousing/reporting solutions']],
#     'minyears': [0]},
#    {'skill': [['components'],
#      ['databases'],
#      ['ETL tools'],
#      ['reporting frameworks']],
#     'minyears': [0]},
#    {'skill': [['Provide time estimations for Developer activities']],
#     'minyears': [0]},
#    {'skill': [['Work closely with PV and UAT teams']], 'minyears': [0]},
#    {'skill': [['provide them with the required support']], 'minyears': [0]},
#    {'skill': [['Perform and provide a detailed system impact analysis']],
#     'minyears': [0]},
#    {'skill': [['a given change request']], 'minyears': [0]},
#    {'skill': [['provide estimates']], 'minyears': [0]},
#    {'skill': [['Lead junior Developers']], 'minyears': [0]},
#    {'skill': [['possibly provide feedback on multiple projects']],
#     'minyears': [0]},
#    {'skill': [['DB2']], 'minyears': [0]},
#    {'skill': [['Postgres Databases']], 'minyears': [0]},
#    {'skill': [['PHI & PII']], 'minyears': [0]},
#    {'skill': [['sensitive data']], 'minyears': [0]}],
#   'professional_background': [{'industry': ['healthcare'],
#     'minyears': [0],
#     'background': [['medical and Rx claims processing'],
#      ['healthcare enrollments'],
#      ['providers']]}]},
#  'preferred': {'education': [{'field_of_study': ['Computer Science',
#      'Related'],
#     'education_level': ["Master's"]}],
#   'credentials': [],
#   'hard_skills': [{'skill': [['Business intelligence'],
#      ['analytics'],
#      ['tool experience'],
#      ['Cognos'],
#      ['Tableau']],
#     'minyears': [0]},
#    {'skill': [['Security standards']], 'minyears': [0]}],
#   'professional_background': []},
#  'responsibility': {'hard_skills': [{'skill': [['Analytical and problem-solving skills']]},
#    {'skill': [['Documentation skills']]},
#    {'skill': [['English language proficiency']]},
#    {'skill': [['Communication of ideas']]},
#    {'skill': [['estimates']]},
#    {'skill': [['scope']]},
#    {'skill': [['timelines']]}]},
#  'job_id': '84b4a4d4-4fdb-45e8-bd40-c5679947f8b0'}

# %%
filtered_jobs = [job for job in job_desc_json if job.get('job_id') in set(final_scores.keys())]

filtered_jobs
# Out:
# [{'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Windsor', 'state': 'CT', 'country': 'US'}],
#    'job_title': ['Salesforce Business Analyst with SCM/ logistics domain Experience'],
#    'tax_terms': ['Direct-hire contract',
#     'Contract Corp-to-Corp',
#     'Contract W2',
#     'Full-time'],
#    'wfh_policy': ['Onsite'],
#    'company_name': ['Techgene'],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Salesforce Business Analyst'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Business Analyst']], 'minyears': [5]},
#     {'skill': [['Microsoft Office Suite']], 'minyears': [0]},
#     {'skill': [['Word']], 'minyears': [0]},
#     {'skill': [['Excel']], 'minyears': [0]},
#     {'skill': [['PowerPoint']], 'minyears': [0]},
#     {'skill': [['Data analysis tools'], ['SQL'], ['Tableau']],
#      'minyears': [0]}],
#    'professional_background': [{'industry': ['SCM', 'logistics'],
#      'minyears': [0],
#      'background': [['Business Analyst']]}]},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Project management methodologies'],
#       ['Agile'],
#       ['Waterfall']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Analyzing business challenges']]},
#     {'skill': [['designing solutions']]},
#     {'skill': [['implementing solutions']]},
#     {'skill': [['driving measurable business impact']]}]},
#   'job_id': 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Dallas', 'state': 'TX', 'country': 'US'}],
#    'job_title': ['Functional Architect - Remote / Telecommute'],
#    'tax_terms': ['Contract', 'Contract Corp to Corp', 'Contract W2'],
#    'wfh_policy': ['Remote'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Functional Architect'],
#    'employment_type': ['Contract'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['JDA'], ['RedPrairie'], ['WMS']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Liaise with business users'],
#       ['client managers'],
#       ['specialists'],
#       ['understand the requirements'],
#       ['problem statements']]},
#     {'skill': [['Owns the overall design',
#        'JDA template',
#        'Supply and Inventory Planning',
#        'meet customer requirements']]},
#     {'skill': [['Guides the template design',
#        'best practices',
#        'high usage',
#        'standard functionality',
#        'repeatability',
#        'efficiency',
#        'scalability',
#        'sustainability']]},
#     {'skill': [['Leads Supply Planning process',
#        'technical design',
#        'build',
#        'testing',
#        'training']]},
#     {'skill': [['Documents all external interface requirements']]},
#     {'skill': [['Supports Business Integration team',
#        'writing Functional Designs'],
#       ['writing Field Mapping Documents'],
#       ['writing Technical Designs']]},
#     {'skill': [['Defines Supply & Inventory Planning data requirements'],
#       ['test scenarios'],
#       ['test cases'],
#       ['associated data requirements']]},
#     {'skill': [['Reporting issues'],
#       ['bugs', 'JDA'],
#       ['tracking their resolution']]},
#     {'skill': [['Demonstrate conference room pilots', 'SMEs']]},
#     {'skill': [['Carrying out Development tasks']]},
#     {'skill': [['Carrying out upgrade tasks']]},
#     {'skill': [['Carrying out support tasks']]},
#     {'skill': [['Reviewing technical specs']]},
#     {'skill': [['Coordinating with the customer'],
#       ['offshore team'],
#       ['resolve queries'],
#       ['clarifications']]}]},
#   'job_id': 'edcd8df0-7dc7-4896-8d28-c435462059b6'},
#  {'details': {'wage': [{'max': 174130,
#      'min': 129806,
#      'pay_type': 'Salary',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': True,
#     'other': ['long-term incentive units',
#      'full range of medical, financial, and/or other benefits'],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': True,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': '', 'state': 'WA', 'country': 'US'},
#     {'city': '', 'state': 'CA', 'country': 'US'}],
#    'job_title': ['Senior Process Engineer Analyst'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Senior Process Engineer Analyst'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Information Systems',
#       'Software Engineering',
#       'Electrical Engineering',
#       'Electronics Engineering',
#       'Related'],
#      'education_level': ["Bachelor's", 'Or Experience']}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['related work experience']], 'minyears': [5]},
#     {'skill': [['Process improvement'],
#       ['quality engineering'],
#       ['industrial engineering']],
#      'minyears': [0]},
#     {'skill': [['ITIL'],
#       ['Dev Ops'],
#       ['Lean'],
#       ['Six Sigma'],
#       ['Capability Maturity Model'],
#       ['CMMI'],
#       ['IT4IT'],
#       ['TOGAF']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Understanding process issues',
#        'the organization',
#        'coming up with creative solutions',
#        'drive cost efficiencies']]},
#     {'skill': [['Using simple processes',
#        'optimize the end-to-end environment']]},
#     {'skill': [['Identifying strengths',
#        'areas for process improvement',
#        'establishing links',
#        'business strategies',
#        'improvement initiatives']]},
#     {'skill': [['Modeling business processes',
#        'a variety of tools',
#        'techniques']]},
#     {'skill': [['Providing knowledge',
#        'expertise',
#        'the design',
#        'improvement of processes']]},
#     {'skill': [['Performing root cause analysis',
#        'creating recommendations',
#        'improvement']]},
#     {'skill': [['Meeting',
#        'business and technical leaders',
#        'identify and scope opportunities',
#        'outline potential value',
#        'return on investment',
#        'identify risks',
#        'constraints']]},
#     {'skill': [['Assisting Senior Architects',
#        'interpreting internal and external business issues',
#        'recommending best practices']]},
#     {'skill': [['Tackling sophisticated problems',
#        'taking a broad perspective',
#        'identify innovative solutions']]},
#     {'skill': [['Analyzing data',
#        'trends',
#        'recommending possible improvements',
#        'solutions']]},
#     {'skill': [['Gathering the tactical and strategic business goals',
#        'provide traceability',
#        'the organization',
#        'mapping them',
#        'metrics',
#        'provide ongoing governance capability']]},
#     {'skill': [['Evaluating existing processes',
#        'interviews',
#        'workshops',
#        'document analysis',
#        'surveys',
#        'Kaizen Events',
#        'user scenarios',
#        'process maps',
#        'task and workflow analysis']]},
#     {'skill': [['Facilitating and leading tiger team meetings']]},
#     {'skill': [['Enumerating',
#        'analyzing',
#        'cataloging',
#        'suggesting improvements',
#        'the strategic, core, and support processes',
#        'the business']]},
#     {'skill': [['Defining the data elements',
#        'the various business units',
#        'the enterprise',
#        'the relationships',
#        'those data elements',
#        'processes',
#        'people',
#        'systems',
#        'other process elements']]},
#     {'skill': [['Evaluating existing processes',
#        'interviews',
#        'workshops',
#        'document analysis',
#        'surveys',
#        'Kaizen Events',
#        'user scenarios',
#        'process maps',
#        'task and workflow analysis']]}]},
#   'job_id': '2fd8af11-4583-4d06-822b-fad7c0c3bc9a'},
#  {'details': {'wage': [{'max': 65,
#      'min': 65,
#      'pay_type': 'Hourly',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['W2 ONLY - FULLY REMOTE SALESFORCE CPQ SYSTEMS ANALYST'],
#    'tax_terms': ['Contract', 'Contract W2'],
#    'wfh_policy': ['Remote'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': ['40 hours/week'],
#    'job_title_base': ['Salesforce CPQ Systems Analyst'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': [],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Salesforce CPQ']], 'minyears': [7]},
#     {'skill': [['Solution design']], 'minyears': [0]},
#     {'skill': [['technical consultation']], 'minyears': [0]},
#     {'skill': [['application integration']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['SAFe methodology']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Provide expert technical advice',
#        'business unit owners',
#        'IT leaders',
#        'project teams',
#        'support teams']]},
#     {'skill': [['Develop application solutions',
#        'business processes',
#        'sales',
#        'opportunity to order']]},
#     {'skill': [['implement application solutions',
#        'business processes',
#        'sales',
#        'opportunity to order']]},
#     {'skill': [['Analyze potential solutions']]},
#     {'skill': [['create technical diagrams']]},
#     {'skill': [['document processes']]},
#     {'skill': [['Identify gaps', 'applications']]},
#     {'skill': [['address gaps', 'applications']]},
#     {'skill': [['offering recommendations', 'improve utilization']]},
#     {'skill': [['Transfer application knowledge', 'the implementation team']]},
#     {'skill': [['participate in solution design']]},
#     {'skill': [['Guide team members', 'documentation methodologies']]},
#     {'skill': [['Guide team members', 'solution modeling']]},
#     {'skill': [['Promote agile methodologies', 'reduce costs']]},
#     {'skill': [['Promote agile methodologies', 'streamline processes']]},
#     {'skill': [['Promote agile methodologies', 'speed up value delivery']]},
#     {'skill': [['Test new application releases']]},
#     {'skill': [['document new application releases']]},
#     {'skill': [['manage functional specifications', 'projects']]},
#     {'skill': [['Collaborate with vendors', 'resolve software bugs']]},
#     {'skill': [['Collaborate with internal teams', 'resolve software bugs']]},
#     {'skill': [['escalate issues']]},
#     {'skill': [['Ensure proper integration',
#        'applications',
#        'other systems',
#        'Financials',
#        'E-commerce']]},
#     {'skill': [['resolve multi-system inconsistencies']]},
#     {'skill': [['Support project status reviews']]},
#     {'skill': [['Support readiness processes']]},
#     {'skill': [['Support end-user fixes']]}]},
#   'job_id': '8bd1bc07-2777-4c8e-89f8-7895e81b0abe'},
#  {'details': {'wage': [{'max': 80,
#      'min': 80,
#      'pay_type': 'Hourly',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': True,
#     'equity': False,
#     'vision': True,
#     'medical': True,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['Systems Integration Engineer III'],
#    'tax_terms': ['Contract', 'Contract W2', 'Contract Independent'],
#    'wfh_policy': [],
#    'company_name': ['Robert Half'],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Systems Integration Engineer'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': ['Does Not Offer Sponsorship']},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Electrical Engineering',
#       'Related'],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['programming languages'],
#       ['Python'],
#       ['Java'],
#       ['C++']],
#      'minyears': [0]},
#     {'skill': [['Middleware and integration technologies']], 'minyears': [0]},
#     {'skill': [['Networking protocols and configurations']], 'minyears': [0]}],
#    'professional_background': [{'industry': [],
#      'minyears': [0],
#      'background': [['Systems Integration Engineer'], ['similar role']]}]},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Collaborate with cross-functional teams',
#        'design and architect integrated systems solutions',
#        'client requirements']]},
#     {'skill': [['Develop system specifications',
#        'compatibility',
#        'scalability']]},
#     {'skill': [['Lead the integration and deployment',
#        'complex systems',
#        'hardware and software components']]},
#     {'skill': [['Conduct testing and debugging',
#        'seamless integration',
#        'optimal performance']]},
#     {'skill': [['Identify and resolve issues',
#        'system integration',
#        'minimal downtime']]},
#     {'skill': [['Provide ongoing support',
#        'integrated systems',
#        'maintenance or performance concerns']]},
#     {'skill': [['Create comprehensive documentation',
#        'system integration processes',
#        'configurations',
#        'troubleshooting procedures']]},
#     {'skill': [['Implement quality assurance measures',
#        'reliability',
#        'stability',
#        'integrated systems']]},
#     {'skill': [['Conduct thorough testing and validation',
#        'integrated solutions']]}]},
#   'job_id': '5cdf2c5a-05fa-40e7-b85b-cefccd795706'},
#  {'details': {'wage': [{'max': 65,
#      'min': 65,
#      'pay_type': 'Hourly',
#      'wage_city': ['Berkeley Heights'],
#      'wage_state': ['NJ']}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Berkeley Heights', 'state': 'NJ', 'country': 'US'}],
#    'job_title': ['JIRA Administrator', 'Sr. Jira Administrator/SME'],
#    'tax_terms': ['Contract', 'Contract W2'],
#    'wfh_policy': ['On-site'],
#    'company_name': ['Primus Software Corporation'],
#    'company_stage': [],
#    'work_schedule': ['Day Shift'],
#    'job_title_base': ['JIRA Administrator'],
#    'employment_type': ['Contract'],
#    'travel_required': {'required': True, 'hours_weekly': 40},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': ['Does Not Offer Sponsorship']},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Jira Administrator']], 'minyears': [5]},
#     {'skill': [['Super User']], 'minyears': [5]},
#     {'skill': [['planning development teams']], 'minyears': [3]},
#     {'skill': [['migrating development teams']], 'minyears': [3]},
#     {'skill': [['onboarding development teams']], 'minyears': [3]},
#     {'skill': [['Jira']], 'minyears': [3]},
#     {'skill': [['enterprise Jira']], 'minyears': [3]},
#     {'skill': [['Jira release management features']], 'minyears': [0]},
#     {'skill': [['building complex dashboards', 'Jira']], 'minyears': [0]},
#     {'skill': [['working with Agile teams']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['training people', 'Jira use']],
#      'minyears': [0]},
#     {'skill': [['training people', 'workflow']], 'minyears': [0]},
#     {'skill': [['training people', 'dashboards']], 'minyears': [0]},
#     {'skill': [['training teams', 'Jira use']], 'minyears': [0]},
#     {'skill': [['training teams', 'workflow']], 'minyears': [0]},
#     {'skill': [['training teams', 'dashboards']], 'minyears': [0]},
#     {'skill': [['training leaders', 'Jira use']], 'minyears': [0]},
#     {'skill': [['training leaders', 'workflow']], 'minyears': [0]},
#     {'skill': [['training leaders', 'dashboards']], 'minyears': [0]},
#     {'skill': [['Confluence']], 'minyears': [0]},
#     {'skill': [['enterprise Confluence']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['planning team members']]},
#     {'skill': [['executing team members']]},
#     {'skill': [['training team members']]},
#     {'skill': [['planning staff']]},
#     {'skill': [['executing staff']]},
#     {'skill': [['training staff']]},
#     {'skill': [['migration effort', 'Enterprise Jira']]}]},
#   'job_id': 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2'},
#  {'details': {'wage': [{'max': 140000,
#      'min': 120000,
#      'pay_type': 'Salary',
#      'wage_city': ['South Lake'],
#      'wage_state': ['TX']}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'South Lake', 'state': 'TX', 'country': 'US'}],
#    'job_title': ['SharePoint Manager'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['SharePoint Manager'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['SharePoint technologies']], 'minyears': [15]},
#     {'skill': [['different SharePoint versions'],
#       ['SP 2013'],
#       ['2016'],
#       ['2019'],
#       ['SP Online']],
#      'minyears': [0]},
#     {'skill': [['SharePoint custom development'], ['SPFx'], ['SPO']],
#      'minyears': [0]},
#     {'skill': [['Customizations using C#', 'On-Prem']], 'minyears': [0]},
#     {'skill': [['Managing end-to-end development project',
#        'Scrum methodologies']],
#      'minyears': [0]}],
#    'professional_background': [{'industry': [],
#      'minyears': [0],
#      'background': [['Technical Project Manager']]}]},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['working with Product Owners',
#        'defining Product Goal',
#        'Milestones']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Develop', 'the project'],
#       ['Develop', 'communication'],
#       ['Develop', 'resource plans'],
#       ['Develop', 'processes']]},
#     {'skill': [['manage the project'],
#       ['manage communication'],
#       ['manage resource plans'],
#       ['manage processes']]},
#     {'skill': [['Share the project vision',
#        'work with onshore team',
#        'drive it through',
#        'meet Project Plan goal']]},
#     {'skill': [['Share the project vision',
#        'work with offshore team',
#        'drive it through',
#        'meet Project Plan goal']]}]},
#   'job_id': 'd8961472-c59c-48d1-a5b5-d49c778fcac5'},
#  {'details': {'wage': [{'max': 70,
#      'min': 70,
#      'pay_type': 'Hourly',
#      'wage_city': ['Columbus'],
#      'wage_state': ['OH']}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Columbus', 'state': 'OH', 'country': 'US'}],
#    'job_title': ['Java/J2EE Architect - Columbus, OH (Hybrid)'],
#    'tax_terms': ['Contract', 'Contract Corp to Corp', 'Contract W2'],
#    'wfh_policy': ['Hybrid'],
#    'company_name': ['Vector Consulting, Inc.'],
#    'company_stage': [],
#    'work_schedule': ['Hybrid'],
#    'job_title_base': ['Java/J2EE Architect'],
#    'employment_type': ['Contract'],
#    'travel_required': {'required': True, 'hours_weekly': 0},
#    'company_industry': ['IT Talent Acquisition Solutions'],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Java']], 'minyears': [10]},
#     {'skill': [['JEE 5']], 'minyears': [10]},
#     {'skill': [['Java EE Batch Architecture']], 'minyears': [10]},
#     {'skill': [['Spring Framework']], 'minyears': [10]},
#     {'skill': [['Java EE Design Patterns']], 'minyears': [10]},
#     {'skill': [['IDE']], 'minyears': [10]},
#     {'skill': [['RAD 7.5']], 'minyears': [10]},
#     {'skill': [['Eclipse']], 'minyears': [10]},
#     {'skill': [['Spring Framework']], 'minyears': [10]},
#     {'skill': [['MVC model']], 'minyears': [10]},
#     {'skill': [['Batch architecture']], 'minyears': [10]},
#     {'skill': [['Web Framework']], 'minyears': [10]},
#     {'skill': [['JSF 2.0 Framework']], 'minyears': [10]},
#     {'skill': [['Messaging']], 'minyears': [10]},
#     {'skill': [['Asynchronous Messaging']], 'minyears': [10]},
#     {'skill': [['JMS']], 'minyears': [10]},
#     {'skill': [['MQ']], 'minyears': [10]},
#     {'skill': [['Persistence']], 'minyears': [10]},
#     {'skill': [['JPA']], 'minyears': [10]},
#     {'skill': [['Java Persistence API 2.0']], 'minyears': [10]},
#     {'skill': [['EJB 3.0']], 'minyears': [10]},
#     {'skill': [['Web Services']], 'minyears': [10]},
#     {'skill': [['JAX-WS Web Services']], 'minyears': [10]},
#     {'skill': [['XML']], 'minyears': [10]},
#     {'skill': [['JAXB']], 'minyears': [10]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Participation in the Ohio STARS project']],
#      'minyears': [0]},
#     {'skill': [['agency STARS-related products'],
#       ['PSRM'],
#       ['PeopleSoft'],
#       ['DataStage'],
#       ['WebSphere ESB']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Architect solutions']]},
#     {'skill': [['design solutions']]},
#     {'skill': [['develop solutions']]},
#     {'skill': [['Development of Web Services']]},
#     {'skill': [['support of Web Services']]},
#     {'skill': [['Provide Production Support',
#        'various eCommerce applications']]},
#     {'skill': [['Infrastructure upgrades', 'technical debt']]},
#     {'skill': [['Migration of eCommerce applications',
#        'upgrade platform',
#        'WAS 9']]},
#     {'skill': [['Migration of eCommerce applications',
#        'upgrade platform',
#        'RAD 9']]},
#     {'skill': [['Migration of eCommerce applications',
#        'upgrade platform',
#        'JAVA 1.8']]},
#     {'skill': [['Enhance eCommerce applications']]},
#     {'skill': [['migrate the backend',
#        'a platform other than Mainframe DB2']]},
#     {'skill': [['front end']]},
#     {'skill': [['back end']]},
#     {'skill': [['batch']]}]},
#   'job_id': 'a25c98ff-be8f-4ea4-b740-e459455d16b8'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Crownsville', 'state': 'MD', 'country': 'US'}],
#    'job_title': ['System Engineer - VMware Cloud Services'],
#    'tax_terms': ['DIRECT_HIRE_CONTRACT',
#     'CONTRACT_CORP_TO_CORP',
#     'CONTRACT_W2',
#     'FULL_TIME'],
#    'wfh_policy': ['Hybrid'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['System Engineer'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': ['Does Not Offer Sponsorship']},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['deploying VMware products',
#        'ESXi',
#        'vCenter']],
#      'minyears': [2]},
#     {'skill': [['configuring VMware products', 'ESXi', 'vCenter']],
#      'minyears': [2]},
#     {'skill': [['securing VMware products', 'ESXi', 'vCenter']],
#      'minyears': [2]},
#     {'skill': [['configuring Windows']], 'minyears': [2]},
#     {'skill': [['securing Windows']], 'minyears': [2]},
#     {'skill': [['configuring Active Directory']], 'minyears': [2]},
#     {'skill': [['securing Active Directory']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'vSphere']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'vCenter']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'ESXi']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'vRealize']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'NSX-T']], 'minyears': [2]},
#     {'skill': [['VMware product line', 'Infrastructure components']],
#      'minyears': [2]},
#     {'skill': [['vCenter']], 'minyears': [2]},
#     {'skill': [['ESX Maintenance activities']], 'minyears': [2]},
#     {'skill': [['patching']], 'minyears': [2]},
#     {'skill': [['upgrades']], 'minyears': [2]},
#     {'skill': [['Installation of VMware ESXi Servers']], 'minyears': [2]},
#     {'skill': [['Troubleshooting of VMware ESXi Servers']], 'minyears': [2]},
#     {'skill': [['Installation of vCenter']], 'minyears': [2]},
#     {'skill': [['Troubleshooting of vCenter']], 'minyears': [2]},
#     {'skill': [['support of VMware environment']], 'minyears': [2]},
#     {'skill': [['support of Windows environment']], 'minyears': [2]},
#     {'skill': [['resolving escalated tickets', 'internal customers']],
#      'minyears': [2]},
#     {'skill': [['Linux administration']], 'minyears': [1]},
#     {'skill': [['UNIX administration']], 'minyears': [1]},
#     {'skill': [['Linux automation']], 'minyears': [1]},
#     {'skill': [['UNIX automation']], 'minyears': [1]},
#     {'skill': [['Oracle dB setup']], 'minyears': [1]},
#     {'skill': [['Oracle dB replication']], 'minyears': [1]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['VMware Experience']], 'minyears': [0]},
#     {'skill': [['Citrix Experience']], 'minyears': [0]},
#     {'skill': [['User profile management']], 'minyears': [0]},
#     {'skill': [['Application Virtualization']], 'minyears': [0]},
#     {'skill': [['Scripting in PowerShell']], 'minyears': [0]},
#     {'skill': [['Migration to AWS lift and shift']], 'minyears': [0]},
#     {'skill': [['Strong knowledge of storage systems']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': []},
#   'job_id': 'bf9aa16e-181d-46fd-9b34-999b21221885'},
#  {'details': {'wage': [{'max': 256500,
#      'min': 138900,
#      'pay_type': 'Salary',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': True,
#     'other': ['range of discounted products and free services',
#      'relocation',
#      'discretionary restricted stock unit awards',
#      'Employee Stock Purchase Plan'],
#     'dental': True,
#     'equity': True,
#     'vision': False,
#     'medical': True,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': True},
#    'location': [],
#    'job_title': ['Distributed Systems Devops Engineer'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': ['Apple'],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Devops Engineer'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': ['Offers Sponsorship']},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Related'],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['DevOps'], ['Site Reliability']],
#      'minyears': [3]},
#     {'skill': [['Hybrid cloud environments']], 'minyears': [0]},
#     {'skill': [['Container orchestration'], ['Kubernetes']], 'minyears': [0]},
#     {'skill': [['Ruby', 'systems automation'],
#       ['Golang', 'systems automation'],
#       ['Python', 'systems automation'],
#       ['Ruby', 'web services'],
#       ['Golang', 'web services'],
#       ['Python', 'web services']],
#      'minyears': [0]},
#     {'skill': [['Troubleshooting skills', 'systems'],
#       ['Troubleshooting skills', 'network', 'TCP/IP'],
#       ['Troubleshooting skills', 'code']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [{'field_of_study': ['Computer Science',
#       'Related'],
#      'education_level': ["Master's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['macOS']], 'minyears': [0]},
#     {'skill': [['Xcode build system']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Serve as a primary point responsible',
#        'the overall health',
#        'performance',
#        'capacity',
#        'our internal service']]},
#     {'skill': [['Assist',
#        'the roll-out',
#        'deployment',
#        'new product features',
#        'installations']]},
#     {'skill': [['Develop tools',
#        'improve our ability',
#        'rapidly deploy',
#        'effectively monitor custom applications',
#        'a large-scale environment']]},
#     {'skill': [['Work closely',
#        'development teams',
#        'ensure the platform',
#        'designed',
#        'operability']]},
#     {'skill': [['Drive standardization efforts', 'multiple services']]},
#     {'skill': [['Identify', 'lead efforts', 'improve automation']]},
#     {'skill': [['Participate', 'an on-call rotation']]}]},
#   'job_id': '195f1df8-b444-4118-ad8f-b2d8a9959c34'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': '', 'state': '', 'country': 'Remote'}],
#    'job_title': [['Data Analyst'], ['Data Specialist']],
#    'tax_terms': [['Contract'], ['Contract W2']],
#    'wfh_policy': ['Remote'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': [['Data Analyst'], ['Data Specialist']],
#    'employment_type': ['Contract'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': [],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['data validation']], 'minyears': [2]},
#     {'skill': [['data integrity']], 'minyears': [2]},
#     {'skill': [['data cleanup']], 'minyears': [2]},
#     {'skill': [['Excel']], 'minyears': [0]},
#     {'skill': [['pulling reports']], 'minyears': [0]},
#     {'skill': [['combining data']], 'minyears': [0]},
#     {'skill': [['VLOOKUPs']], 'minyears': [0]},
#     {'skill': [['Salesforce Sales Cloud'], ['other CRMs']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['MS Excel']], 'minyears': [0]},
#     {'skill': [['V-Lookups']], 'minyears': [0]},
#     {'skill': [['Pivot tables']], 'minyears': [0]},
#     {'skill': [['Salesforce']], 'minyears': [0]},
#     {'skill': [['searching information']], 'minyears': [0]},
#     {'skill': [['entering information']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Take charge of data cleansing efforts',
#        'Excel',
#        'accuracy',
#        'reliability']]},
#     {'skill': [['Collaborate closely',
#        'cross-functional teams',
#        'data',
#        'prepared appropriately']]},
#     {'skill': [['Maintain system documentation']]},
#     {'skill': [['update leads']]},
#     {'skill': [['update opportunities']]},
#     {'skill': [['align external data',
#        'internal B2B and B2C Salesforce database']]}]},
#   'job_id': '96051542-318e-4fd1-aea9-035cd9a74fe5'},
#  {'details': {'wage': [{'max': 50,
#      'min': 40,
#      'pay_type': 'Hourly',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': ['Comprehensive benefits package'],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': '', 'state': '', 'country': 'Remote'}],
#    'job_title': ['Integration Project Manager', 'Project Manager'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': ['Remote'],
#    'company_name': ['Apex Systems'],
#    'company_stage': [],
#    'work_schedule': ['100% Remote'],
#    'job_title_base': ['Project Manager'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': ['IT Services'],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Information Technology',
#       'Related'],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['IT Project Management']], 'minyears': [4]},
#     {'skill': [['Information Security']], 'minyears': [0]},
#     {'skill': [['Risk Management']], 'minyears': [0]},
#     {'skill': [['Mergers and Acquisitions']], 'minyears': [0]},
#     {'skill': [['Automating reports', 'Logic Gate']], 'minyears': [0]},
#     {'skill': [['Automating reports', 'Power Bi']], 'minyears': [0]},
#     {'skill': [['Automating reports', 'Tableau']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['automating reports', 'Logic Gate']],
#      'minyears': [0]},
#     {'skill': [['automating reports', 'Power Bi']], 'minyears': [0]},
#     {'skill': [['automating reports', 'Tableau']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Work closely with cross-functional teams',
#        'infrastructure',
#        'security',
#        'operations',
#        'business stakeholders',
#        'ensure project delivery',
#        'aligns with business requirements']]},
#     {'skill': [['Support the planning and execution',
#        'IT projects',
#        'start to finish',
#        'defining project scope',
#        'goals',
#        'deliverables']]},
#     {'skill': [['Develop detailed project plans',
#        'timelines',
#        'budgets',
#        'manage project risks',
#        'issues']]},
#     {'skill': [['Conduct regular project meetings',
#        'review project status',
#        'provide updates',
#        'ensure project team members',
#        'aligned']]},
#     {'skill': [['Identify',
#        'assess',
#        'design remediation action plans',
#        'data issues',
#        'monitor their progress',
#        'completion']]},
#     {'skill': [['Analyze risks',
#        'related to data',
#        'monitor key indicators',
#        'produce monthly risk governance reports',
#        'materials',
#        'management']]},
#     {'skill': [['Ensure project delivery',
#        'within budget',
#        'time constraints',
#        'meeting quality standards']]},
#     {'skill': [['Effectively communicate project status',
#        'risks',
#        'issues',
#        'stakeholders',
#        'senior management']]},
#     {'skill': [['Identify areas',
#        'process improvement',
#        'implement solutions',
#        'optimize project delivery']]},
#     {'skill': [['Support multiple',
#        'simultaneous projects',
#        'rapid development environment',
#        'involving different types',
#        'technical',
#        'business partners']]},
#     {'skill': [['Track',
#        'prepare senior management reporting documents',
#        'take ownership',
#        'follow-up',
#        'relevant stakeholders']]},
#     {'skill': [['Track tasks',
#        'establish accountability',
#        'manage risks',
#        'escalate issues']]},
#     {'skill': [['Effectively prioritize tasks',
#        'assignments',
#        'various projects',
#        'keep them on track']]},
#     {'skill': [['Facilitate the implementation',
#        'projects',
#        'ensuring timely',
#        'efficient execution']]},
#     {'skill': [['Overcome obstacles', 'barriers', 'delay project progress']]},
#     {'skill': [['Gather project requirements',
#        'assess objectives',
#        'goals',
#        'project scopes',
#        'multiple initiatives']]},
#     {'skill': [['Manage interdependencies',
#        'dependencies',
#        'projects',
#        'programs',
#        'collaboration',
#        'cross-functional project planning',
#        'comprehensive reporting']]}]},
#   'job_id': 'bb464343-964a-4eb5-851d-a7cc5753625e'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': ['Paid-Time-Off',
#      'Paid Holidays',
#      'Life and Accidental Death Insurance',
#      'Short & Long Term Disability Insurance',
#      'a variety of other perks'],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': True,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['Project Manager'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': ['HTC Global Services'],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Project Manager'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Agile methodologies']], 'minyears': [0]},
#     {'skill': [['JIRA'], ['project management software']], 'minyears': [0]},
#     {'skill': [['Using Agile methodologies', 'data projects']],
#      'minyears': [0]},
#     {'skill': [['Creating reports',
#        'senior management',
#        'project statuses',
#        'metrics']],
#      'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Six Sigma'],
#       ['equivalent process improvement training']],
#      'minyears': [0]},
#     {'skill': [['P&C insurance domain experience']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Refine project management procedures',
#        'improve efficiency']]},
#     {'skill': [['automate project management procedures',
#        'improve efficiency']]},
#     {'skill': [['Manage JIRA', 'projects']]},
#     {'skill': [['Manage JIRA', 'data teams']]},
#     {'skill': [['monitor progress', 'Data Science projects']]},
#     {'skill': [['monitor progress', 'Data Engineering projects']]},
#     {'skill': [['report progress', 'Data Science projects']]},
#     {'skill': [['report progress', 'Data Engineering projects']]},
#     {'skill': [['Coordinate', 'AI program']]},
#     {'skill': [['manage', 'AI program']]},
#     {'skill': [['Coordinate data', 'analytics vendor pilots']]},
#     {'skill': [['manage data', 'analytics vendor pilots']]},
#     {'skill': [['Design reports', 'JIRA data', 'track team progress']]},
#     {'skill': [['create reports', 'JIRA data', 'track team progress']]},
#     {'skill': [['Design dashboards', 'JIRA data', 'track team progress']]},
#     {'skill': [['create dashboards', 'JIRA data', 'track team progress']]},
#     {'skill': [['Interact', 'business units']]},
#     {'skill': [['Interact', 'project team members']]},
#     {'skill': [['ensure clarity', 'business objectives']]},
#     {'skill': [['ensure clarity', 'project scope']]},
#     {'skill': [['ensure clarity', 'goals']]},
#     {'skill': [['ensure clarity', 'expected outcomes']]},
#     {'skill': [['ensure clarity', 'deliverables']]},
#     {'skill': [['Coordinate', 'vendors', 'project']]},
#     {'skill': [['manage', 'vendors', 'project']]},
#     {'skill': [['Perform project estimating']]},
#     {'skill': [['Perform project planning']]},
#     {'skill': [['Perform project tracking']]},
#     {'skill': [['Perform problem resolution']]},
#     {'skill': [['Perform reporting', 'appropriate tools']]},
#     {'skill': [['Perform reporting', 'approved processes']]},
#     {'skill': [['Perform reporting', 'project management techniques']]},
#     {'skill': [['Capture next steps', 'projects']]},
#     {'skill': [['ensure', 'next steps', 'performed', 'timely manner']]},
#     {'skill': [['Coordinate project communications']]},
#     {'skill': [['follow-up', 'all involved parties']]},
#     {'skill': [['Identify project stakeholders']]},
#     {'skill': [['provide appropriate communication', 'stakeholders']]},
#     {'skill': [['provide statuses', 'stakeholders']]},
#     {'skill': [['facilitate accurate decisions']]},
#     {'skill': [['facilitate timely decisions']]},
#     {'skill': [['Organize project meetings']]},
#     {'skill': [['Recommend opportunities', 'improve analytics processes']]},
#     {'skill': [['Submit requests', 'IT project resources']]},
#     {'skill': [['follow-up', 'requests', 'IT project resources']]},
#     {'skill': [['Identify potential project risks']]},
#     {'skill': [['develop mitigation strategies']]},
#     {'skill': [['Ensure appropriate documentation',
#        'delivered',
#        'project']]}]},
#   'job_id': '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251'},
#  {'details': {'wage': [{'max': 100000,
#      'min': 100000,
#      'pay_type': 'Salary',
#      'wage_city': ['San Francisco'],
#      'wage_state': ['CA']}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': True,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'San Francisco', 'state': 'CA', 'country': 'US'}],
#    'job_title': ['Technology Sales Manager'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Sales Manager'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['selling business solutions', 'Analytics'],
#       ['selling business solutions', 'Salesforce'],
#       ['selling business solutions', 'Community Management'],
#       ['selling business solutions', 'Marketing Automation'],
#       ['selling business solutions', 'Microsoft Services'],
#       ['selling business solutions', 'large enterprise customers'],
#       ['selling business solutions', 'global enterprise customers']],
#      'minyears': [8]},
#     {'skill': [['Track record', 'software sales']], 'minyears': [0]},
#     {'skill': [['Track record', 'business development']], 'minyears': [0]},
#     {'skill': [['Track record', 'account management']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Develop a Go-to-Market Sales Plan']]},
#     {'skill': [['Actively explore new opportunities', 'business growth']]},
#     {'skill': [['acquiring new accounts']]},
#     {'skill': [['generating revenue', 'the Enterprise segment']]},
#     {'skill': [['Build a robust portfolio', 'prospects']]},
#     {'skill': [['drive sales growth']]},
#     {'skill': [['Obtain new customers', 'various Professional services']]},
#     {'skill': [['exploring similar opportunities', 'our client base']]},
#     {'skill': [['Execute sales goals']]},
#     {'skill': [['provide timely submission', 'pipeline reports']]},
#     {'skill': [['provide timely submission', 'forecasts']]},
#     {'skill': [['Assist in developing marketing plans']]},
#     {'skill': [['target a diverse set', 'potential customers']]},
#     {'skill': [['generate qualified leads']]},
#     {'skill': [['generate qualified opportunities']]}]},
#   'job_id': 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db'},
#  {'details': {'wage': [{'max': 70,
#      'min': 50,
#      'pay_type': 'Contract',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['Mobile Lead Developer - Remote'],
#    'tax_terms': ['Contract', 'Contract W2'],
#    'wfh_policy': ['Remote'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Mobile Lead Developer'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Engineering',
#       'Related'],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['mobile development']], 'minyears': [9]},
#     {'skill': [['SwiftUI']], 'minyears': [0]},
#     {'skill': [['Objective-C']], 'minyears': [0]},
#     {'skill': [['Kotlin']], 'minyears': [0]},
#     {'skill': [['Java']], 'minyears': [0]},
#     {'skill': [['leading a team of developers',
#        'delivery of mobile applications']],
#      'minyears': [0]},
#     {'skill': [['mobile architecture patterns']], 'minyears': [0]},
#     {'skill': [['design principles']], 'minyears': [0]},
#     {'skill': [['best practices']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [{'field_of_study': ['Computer Science',
#       'Engineering',
#       'Related'],
#      'education_level': ["Master's"]}],
#    'credentials': [],
# ...
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Junior Dynamic 365'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Entry Level'],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Dynamics 365']], 'minyears': [1]},
#     {'skill': [['Azure Cloud']], 'minyears': [1]},
#     {'skill': [['Azure DevOps']], 'minyears': [1]},
#     {'skill': [['Powershell']], 'minyears': [1]},
#     {'skill': [['JavaScript']], 'minyears': [1]},
#     {'skill': [['YAML']], 'minyears': [1]},
#     {'skill': [['Deploying Dynamics application']], 'minyears': [1]},
#     {'skill': [['Deploying Azure application']], 'minyears': [1]},
#     {'skill': [['front-line customer support']], 'minyears': [1]},
#     {'skill': [['service desk']], 'minyears': [1]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['.NET']], 'minyears': [0]},
#     {'skill': [['C#']], 'minyears': [0]},
#     {'skill': [['Visual Studio']], 'minyears': [0]},
#     {'skill': [['MVC']], 'minyears': [0]},
#     {'skill': [['Azure SQL Server']], 'minyears': [0]},
#     {'skill': [['Data Export Service']], 'minyears': [0]},
#     {'skill': [['Azure Synapse']], 'minyears': [0]},
#     {'skill': [['SSIS']], 'minyears': [0]},
#     {'skill': [['Azure Data Factory']], 'minyears': [0]},
#     {'skill': [['Azure Logic Apps']], 'minyears': [0]},
#     {'skill': [['Power Automate']], 'minyears': [0]},
#     {'skill': [['Cloud Flows']], 'minyears': [0]},
#     {'skill': [['Azure Command Line Interface']], 'minyears': [0]},
#     {'skill': [['Azure Key Vault']], 'minyears': [0]},
#     {'skill': [['Managed Identity']], 'minyears': [0]},
#     {'skill': [['Azure Monitor']], 'minyears': [0]},
#     {'skill': [['Application Insights']], 'minyears': [0]},
#     {'skill': [['Azure Active Directory']], 'minyears': [0]},
#     {'skill': [['AAD']], 'minyears': [0]},
#     {'skill': [['oauth 2.0']], 'minyears': [0]},
#     {'skill': [['Canvas Apps']], 'minyears': [0]},
#     {'skill': [['Power Apps Portals']], 'minyears': [0]},
#     {'skill': [['Azure Function Apps']], 'minyears': [0]},
#     {'skill': [['Azure Service Bus']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Assist issue triage']]},
#     {'skill': [['lead issue triage']]},
#     {'skill': [['analysis']]},
#     {'skill': [['resolution in production environment']]},
#     {'skill': [['Actively participate',
#        'DevOps Product Delivery Organization']]},
#     {'skill': [['agile ceremonies']]},
#     {'skill': [['Provide technical consulting support', 'PDO teams']]}]},
#   'job_id': '181b9a3d-71ca-420e-8ea8-08b348ad69f2'},
#  {'details': {'wage': [{'max': 85000,
#      'min': 85000,
#      'pay_type': 'Salary',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': True,
#     'hsa': True,
#     'bonus': False,
#     'other': ['Profit sharing plan', 'Annual increases', 'Up to 4 weeks PTO'],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': True,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['Tableau Developer'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': ['Remote'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Tableau Developer'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Tableau']], 'minyears': [2]},
#     {'skill': [['Data modeling']], 'minyears': [0]},
#     {'skill': [['administration']], 'minyears': [0]},
#     {'skill': [['Managing permissions', 'data access']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Making data available',
#        'the enterprise data warehouse',
#        'Tableau']]},
#     {'skill': [['Managing permissions']]},
#     {'skill': [['Ensuring the quality', 'data joins']]},
#     {'skill': [['Integrating new data sources']]},
#     {'skill': [['Working', 'the BI team']]}]},
#   'job_id': '639fb093-26a8-4745-9656-ee93f3b79f19'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Dallas', 'state': 'TX', 'country': 'US'}],
#    'job_title': ['CLM (Contract Lifecycle Management) Solution Architect'],
#    'tax_terms': ['Direct-hire contract',
#     'Contract independent',
#     'Contract corp-to-corp',
#     'Contract W2',
#     'Full-time'],
#    'wfh_policy': [],
#    'company_name': ['VDart Inc'],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Solution Architect'],
#    'employment_type': [],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': ['Digital Technology Solutions'],
#    'experience_level': [],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Operating a Contract Lifecycle Management process']],
#      'minyears': [0]},
#     {'skill': [['Workflows']], 'minyears': [0]},
#     {'skill': [['workflow step configurations']], 'minyears': [0]},
#     {'skill': [['workflow debugging']], 'minyears': [0]},
#     {'skill': [['eForms']], 'minyears': [0]},
#     {'skill': [['Smart Rules']], 'minyears': [0]},
#     {'skill': [['Document generation']], 'minyears': [0]},
#     {'skill': [['templates creation']], 'minyears': [0]},
#     {'skill': [['JavaScript']], 'minyears': [0]},
#     {'skill': [['C#']], 'minyears': [0]},
#     {'skill': [['Working in Agile environments']], 'minyears': [0]},
#     {'skill': [['Responding to contract change requests']], 'minyears': [0]},
#     {'skill': [['DocuSign']], 'minyears': [0]},
#     {'skill': [['Salesforce']], 'minyears': [0]},
#     {'skill': [['DocuSign integration']], 'minyears': [0]},
#     {'skill': [['eSignature']], 'minyears': [0]},
#     {'skill': [['Using Jira']], 'minyears': [0]},
#     {'skill': [['Confluence']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['CLM']], 'minyears': [0]},
#     {'skill': [['Jira']], 'minyears': [0]},
#     {'skill': [['Confluence']], 'minyears': [0]},
#     {'skill': [['Apttus']], 'minyears': [0]}],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Participate in design sessions']]},
#     {'skill': [['review options']]},
#     {'skill': [['provide recommendations']]}]},
#   'job_id': '65ad643c-f389-494e-aaba-210e41917b8d'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': ['Comprehensive benefits',
#      'Continuous learning opportunities',
#      'Diverse, equitable and inclusive workplace',
#      'Employee Resource Groups (ERGs)'],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': '', 'state': '', 'country': 'US'}],
#    'job_title': ['Cybersecurity & Technology Audit Internship (Summer 2025)'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': [],
#    'company_name': ['Liberty Mutual'],
#    'company_stage': [],
#    'work_schedule': ['11-week internship'],
#    'job_title_base': ['Cybersecurity & Technology Audit Intern'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': ['Insurance'],
#    'experience_level': ['Internship'],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': ['Business Management',
#       'Management Information Systems',
#       'Computer Science',
#       'Related'],
#      'education_level': ["Current Bachelor's Student"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Technical programs'], ['Excel']],
#      'minyears': [0]}],
#    'professional_background': [{'industry': [],
#      'minyears': [0],
#      'background': [['Work Experience']]}]},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Interviewing personnel']]},
#     {'skill': [['Performing testwork']]},
#     {'skill': [['Analyzing results']]},
#     {'skill': [['Communicating issues', 'managers']]},
#     {'skill': [['Participating in audit project teams',
#        'complete risk assessments',
#        'control evaluations',
#        'IT areas under review']]}]},
#   'job_id': '53acdd0a-467a-413e-9486-42a2b86b5c66'},
#  {'details': {'wage': [{'max': 70,
#      'min': 65,
#      'pay_type': 'Hourly',
#      'wage_city': [],
#      'wage_state': []}],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': ['Paid sick leave'],
#     'dental': True,
#     'equity': False,
#     'vision': True,
#     'medical': True,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [],
#    'job_title': ['Senior Product Designer - Data - Remote'],
#    'tax_terms': ['Direct-hire'],
#    'wfh_policy': ['Remote'],
#    'company_name': ["One of the world's leading providers of news and information-based tools to professionals"],
#    'company_stage': [],
#    'work_schedule': [],
#    'job_title_base': ['Senior Product Designer'],
#    'employment_type': ['Full-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [],
#    'credentials': [],
#    'hard_skills': [{'skill': [['product designer'], ['UX/UI designer']],
#      'minyears': [4]},
#     {'skill': [['Data visualization']], 'minyears': [0]},
#     {'skill': [['Designing data analytics tools']], 'minyears': [0]},
#     {'skill': [['Designing reporting tools']], 'minyears': [0]},
#     {'skill': [['Figma']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': []},
#   'job_id': '2b2477c7-fafb-411f-b890-11cbb24d02e0'},
#  {'details': {'wage': [],
#    'benefits': {'fsa': False,
#     'hsa': False,
#     'bonus': False,
#     'other': [],
#     'dental': False,
#     'equity': False,
#     'vision': False,
#     'medical': False,
#     '401k_match': False,
#     'mental_health': False,
#     'unlimited_pto': False,
#     'tuition_reimbursement': False},
#    'location': [{'city': 'Dallas', 'state': 'TX', 'country': 'US'},
#     {'city': 'Jersey City', 'state': 'NJ', 'country': 'US'},
#     {'city': 'Atlanta', 'state': 'GA', 'country': 'US'},
#     {'city': 'Charlotte', 'state': 'NC', 'country': 'US'}],
#    'job_title': ['OpenShift Architect'],
#    'tax_terms': ['Direct-hire', 'Contract W2'],
#    'wfh_policy': ['Hybrid'],
#    'company_name': [],
#    'company_stage': [],
#    'work_schedule': ['3 days hybrid'],
#    'job_title_base': ['Architect'],
#    'employment_type': ['Full-time', 'Part-time'],
#    'travel_required': {'required': False, 'hours_weekly': 0},
#    'company_industry': [],
#    'experience_level': ['Senior'],
#    'work_authorization': []},
#   'mandatory': {'education': [{'field_of_study': ['Computer Science',
#       'Engineering',
#       'Related'],
#      'education_level': ["Bachelor's"]}],
#    'credentials': [],
#    'hard_skills': [{'skill': [['Architect', 'Java applications environment']],
#      'minyears': [0]},
#     {'skill': [['OpenShift']], 'minyears': [0]},
#     {'skill': [['deployment']], 'minyears': [0]},
#     {'skill': [['configuration']], 'minyears': [0]},
#     {'skill': [['management']], 'minyears': [0]},
#     {'skill': [['Java']], 'minyears': [0]},
#     {'skill': [['Spring Framework']], 'minyears': [0]},
#     {'skill': [['related technologies']], 'minyears': [0]},
#     {'skill': [['CI/CD pipelines']], 'minyears': [0]},
#     {'skill': [['DevOps practices']], 'minyears': [0]}],
#    'professional_background': []},
#   'preferred': {'education': [{'field_of_study': ['Computer Science',
#       'Engineering',
#       'Related'],
#      'education_level': ["Master's"]}],
#    'credentials': [],
#    'hard_skills': [],
#    'professional_background': []},
#   'responsibility': {'hard_skills': [{'skill': [['Design',
#        'scalable architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['Design',
#        'reliable architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['Design',
#        'secure architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['implement scalable architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['implement reliable architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['implement secure architectures',
#        'Java applications',
#        'OpenShift']]},
#     {'skill': [['Develop architectural blueprints']]},
#     {'skill': [['Develop detailed documentation', 'guide development teams']]},
#     {'skill': [['Ensure alignment', 'industry best practices']]},
#     {'skill': [['Ensure alignment', 'company standards']]},
#     {'skill': [['Lead deployment', 'OpenShift clusters']]},
#     {'skill': [['Lead configuration', 'OpenShift clusters']]},
#     {'skill': [['Lead management', 'OpenShift clusters']]},
#     {'skill': [['Optimize OpenShift environments', 'performance']]},
#     {'skill': [['Optimize OpenShift environments', 'scalability']]},
#     {'skill': [['Optimize OpenShift environments', 'cost-efficiency']]},
#     {'skill': [['Implement CI/CD pipelines', 'OpenShift tools']]},
#     {'skill': [['integrate CI/CD pipelines', 'existing DevOps processes']]},
#     {'skill': [['Provide technical leadership',
#        'development',
#        'Java applications']]},
#     {'skill': [['Provide technical leadership',
#        'deployment',
#        'Java applications']]},
#     {'skill': [['Collaborate', 'development teams']]},
#     {'skill': [['ensure code quality']]},
#     {'skill': [['ensure performance']]},
#     {'skill': [['ensure security']]},
#     {'skill': [['Troubleshoot',
#        'complex technical issues',
#        'Java applications']]},
#     {'skill': [['resolve complex technical issues', 'Java applications']]},
#     {'skill': [['Work closely', 'cross-functional teams']]},
#     {'skill': [['Mentor', 'junior architects']]},
#     {'skill': [['Mentor', 'developers']]},
#     {'skill': [['guide junior architects']]},
#     {'skill': [['guide developers']]},
#     {'skill': [['Participate', 'architectural reviews']]},
#     {'skill': [['provide constructive feedback']]},
#     {'skill': [['Stay updated', 'latest trends', 'cloud computing']]},
#     {'skill': [['Stay updated', 'latest trends', 'OpenShift']]},
#     {'skill': [['Stay updated', 'latest trends', 'Java development']]},
#     {'skill': [['Propose innovative solutions',
#        'improve application performance']]},
#     {'skill': [['implement innovative solutions',
#        'improve application performance']]},
#     {'skill': [['Propose innovative solutions',
#        'improve developer productivity']]},
#     {'skill': [['implement innovative solutions',
#        'improve developer productivity']]},
#     {'skill': [['Drive continuous improvement initiatives',
#        'enhance overall architecture']]},
#     {'skill': [['Drive continuous improvement initiatives',
#        'enhance development processes']]}]},
#   'job_id': 'a45a153b-9da6-4c44-9390-b46a38181eca'}]

# %%
len(filtered_jobs)
# Out:
# 34
