# %%
# %%capture
import os
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer, util
import json
import spacy
from functools import lru_cache
import torch
from utils.semantic_similarity import nlp_similarity_cached # import first
from utils.semantic_similarity import sentence_model # import second

current_wd = os.getcwd()

def safe_json_loads(val):
    try:
        return json.loads(val)
    except json.JSONDecodeError:
        print(f"Error parsing JSON: {val}")
        return None

job_desc_data = pd.read_excel(os.path.join(current_wd, "data", "sample_des_extractions_test_final_3.25.25.xlsx"))
resume_data = pd.read_excel(os.path.join(current_wd, "data", "sample_res_extractions_final_3.18.25.xlsx"))

job_desc_data["job_desc_parsed"] = job_desc_data["extracted"].apply(safe_json_loads)
resume_data["resume_parsed"] = resume_data["extracted"].apply(safe_json_loads)

job_desc_json = job_desc_data['job_desc_parsed']
resume_json = resume_data['resume_parsed']

def append_job_id_to_job_desc(row):
    job_id = row['id']
    job_desc = row['job_desc_parsed']

    if job_desc is None:
        return None
    
    if isinstance(job_desc, str):
        job_desc = safe_json_loads(job_desc)
        if job_desc is None:
            return None
    
    job_desc['job_id'] = job_id
    return job_desc

job_desc_data['job_desc_json'] = job_desc_data.apply(append_job_id_to_job_desc, axis=1)

# %%
def extract_all_strings_from_json(j):
    """
    Recursively extracts all non-empty strings from a JSON-like object (dict or list).
    """
    result = []
    if isinstance(j, dict):
        for v in j.values():
            result.extend(extract_all_strings_from_json(v))
    elif isinstance(j, list):
        for item in j:
            if isinstance(item, str):
                s = item.strip()
                if s:
                    result.append(s)
            else:
                result.extend(extract_all_strings_from_json(item))
    return result

# Precompute Embeddings from a list of JSONS
def precompute_embeddings_for_json_list(json_list, batch_size=64):
    """
    Iterates over a list (or Series) of JSON objects, extracts all non-empty strings
    from each JSON, computes embeddings for all unique strings in batches, and returns
    a dictionary mapping each unique string to its embedding.
    
    Parameters:
      json_list (iterable): A list (or Series) of JSON objects (dicts).
      batch_size (int): Batch size for encoding.
      
    Returns:
      dict: A mapping from string to its embedding.
    """
    all_strings = set()
    for j in json_list:
        if j is None:
            continue
        strings = extract_all_strings_from_json(j)
        all_strings.update(strings)
    
    all_strings = list(all_strings)
    if all_strings:
        embeddings = sentence_model.encode(all_strings, batch_size=batch_size, convert_to_tensor=False)
    else:
        embeddings = np.zeros((0, sentence_model.get_sentence_embedding_dimension()))
    
    string_to_emb = {s: emb for s, emb in zip(all_strings, embeddings)}
    return string_to_emb

# Now call the function with your list of job description JSON objects:
embeddings = precompute_embeddings_for_json_list(job_desc_json, batch_size=64)

# %%
import json
from utils.safe_averages import safe_average

# ---------------------------
# FINAL OVERALL MATCH SCORE
# ---------------------------
def calculate_overall_match_score(job_json, resume_json,
                                  skill_weight=0.20,
                                  education_weight=0.20,
                                  responsibilities_weight=0.20,
                                  credentials_weight=0.20,
                                  background_weight=0.20):
    """
    Calculates the final overall match score as a safe average of the available section scores.
    If a section has no requirements, its score is returned as None and is ignored in the overall average.
    Sections include:
      - Skills
      - Education
      - Responsibilities
      - Credentials
      - Professional Background (the combined background/industry score)
    """
    skill_dict = calculate_overall_skill_match_score(job_json, resume_json)
    edu_dict = calculate_overall_education_match_score(job_json, resume_json)
    resp_dict = calculate_overall_responsibilities_match_score(job_json, resume_json)
    cred_dict = calculate_overall_credentials_score(job_json, resume_json)
    bg_dict = calculate_overall_background_score(job_json, resume_json)
    
    sections = []
    if skill_dict["overall_skill_score"] is not None:
        sections.append(skill_dict["overall_skill_score"])
    if edu_dict["overall_education_score"] is not None:
        sections.append(edu_dict["overall_education_score"])
    if resp_dict["overall_responsibilities_score"] is not None:
        sections.append(resp_dict["overall_responsibilities_score"])
    if cred_dict["overall_credentials_score"] is not None:
        sections.append(cred_dict["overall_credentials_score"])
    if bg_dict["overall_professional_background_score"] is not None:
        sections.append(bg_dict["overall_professional_background_score"])
    
    overall_match = safe_average(sections)
    job_id = job_json.get("id")
    
    final_result = {
        "job_id": job_id,
        "skills": {**skill_dict, "job_id": job_id},
        "education": {**edu_dict, "job_id": job_id},
        "responsibilities": {**resp_dict, "job_id": job_id},
        "credentials": {**cred_dict, "job_id": job_id},
        "professional_background": {**bg_dict, "job_id": job_id},
        "overall_match_score": overall_match
    }
    
    print(f"\nFinal Overall Match Score: {overall_match}")
    return final_result

# # ---------------------------
# # Example Usage:
# # (Assuming job_desc_json and resume_json are your lists/Series of job and resume JSON objects)
# result = calculate_overall_match_score(job_json=job_desc_json[47], resume_json=resume_json[2])
# print(result)

# %%
resultsA = nlp_similarity_cached("create customized salesforce applications", "developed custom applications")
resultsB = nlp_similarity_cached("programmed personalized applications", "developed custom applications")

print(resultsA)
print(resultsB)
# Out:
# 0.8130134741465253
# 0.7504750887552899

# %% [markdown]
# #### Skill Matching

# %%
# SECTION 1: SKILLS MATCHING
from utils.mandatory_skill_score import calculate_mandatory_skill_scores
from utils.preferred_skill_score import calculate_preferred_skill_scores

mandatory_skill_scores = calculate_mandatory_skill_scores(job_json_list=job_desc_json, resume_json=resume_json[7])
preferred_skill_scores = calculate_preferred_skill_scores(job_json_list=job_desc_json, resume_json=resume_json[7])

print(mandatory_skill_scores)
print(preferred_skill_scores)
# Out:
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'mandatory_skill_score': 0.5953992251996643}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'mandatory_skill_score': 0.6396935156413488}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'mandatory_skill_score': 0.45130528722490587}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'mandatory_skill_score': 0.6697338918844862}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'mandatory_skill_score': 0.5970853567123414}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'mandatory_skill_score': 0.6772453884283703}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'mandatory_skill_score': 0.0}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'mandatory_skill_score': 0.5811061342557273}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'mandatory_skill_score': 0.5575330257415774}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'mandatory_skill_score': 0.7499877620827068}, '75a94499-c585-4181-b4de-09f1355a18a2': {'mandatory_skill_score': 0.7783831980493335}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'mandatory_skill_score': 0.6601205801813859}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_skill_score': 0.7860985994338991}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'mandatory_skill_score': 0.5150486760669285}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_skill_score': 0.5533769428730012}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'mandatory_skill_score': 0.6049178116493399}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'mandatory_skill_score': 0.8017839590708417}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_skill_score': 0.5699568669001263}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'mandatory_skill_score': 0.7564182656782646}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_skill_score': 0.5648240923881531}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'mandatory_skill_score': 0.0}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'mandatory_skill_score': 0.0}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'mandatory_skill_score': 0.6791368971268337}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_skill_score': 0.7202710034670654}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'mandatory_skill_score': 0.807896653811137}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_skill_score': 0.7311100363731386}, 'ac212808-481d-4eba-a913-e04f86e660db': {'mandatory_skill_score': 0.6662870451571451}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'mandatory_skill_score': 0.5320566835857575}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'mandatory_skill_score': 0.7108238493954695}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'mandatory_skill_score': 0.7703759496410689}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'mandatory_skill_score': 0.6670288818853872}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'mandatory_skill_score': 0.4498190134763719}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'mandatory_skill_score': 0.4989258527755739}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'mandatory_skill_score': 0.6968484037025}, '23092c01-f933-4711-ac83-cbc310045763': {'mandatory_skill_score': 0.6052231869349879}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'mandatory_skill_score': 0.7290629192634867}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'mandatory_skill_score': 0.7012479765547649}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'mandatory_skill_score': 0.5942066676086851}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'mandatory_skill_score': 0.696403883752369}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'mandatory_skill_score': 0.7657882151780305}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'mandatory_skill_score': 0.7312161823113761}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'mandatory_skill_score': 0.7620685895284017}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'mandatory_skill_score': 0.6981486678123475}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'mandatory_skill_score': 0.7301259727189034}, '44221648-dbaf-4b42-af68-0703ebb16835': {'mandatory_skill_score': 0.8346125748422413}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'mandatory_skill_score': 0.7453928987185161}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'mand ...
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'preferred_skill_score': 0.748574495315552}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'preferred_skill_score': 0.7958972874809715}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'preferred_skill_score': 0.9023809035619101}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'preferred_skill_score': 0.8489240805308026}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'preferred_skill_score': 0.7864317893981936}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'preferred_skill_score': 0.5706955009036595}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'preferred_skill_score': 0.8916385571161908}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'preferred_skill_score': 0.6751931971973846}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'preferred_skill_score': None}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'preferred_skill_score': 0.8550529707045784}, '75a94499-c585-4181-b4de-09f1355a18a2': {'preferred_skill_score': 0.6758296671840881}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'preferred_skill_score': 0.6617155273755393}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'preferred_skill_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'preferred_skill_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'preferred_skill_score': 0.6288245916366579}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'preferred_skill_score': 0.570046784480413}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'preferred_skill_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'preferred_skill_score': 0.6919345404162554}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'preferred_skill_score': 0.7667752703030907}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'preferred_skill_score': 0.5592267645729915}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'preferred_skill_score': 0.7132670879364016}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'preferred_skill_score': 0.7238171451232013}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'preferred_skill_score': 0.9291030565897626}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'preferred_skill_score': 0.7404390289669947}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'preferred_skill_score': 0.7068855166435244}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'preferred_skill_score': 0.6998386912875708}, 'ac212808-481d-4eba-a913-e04f86e660db': {'preferred_skill_score': None}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'preferred_skill_score': 0.6203128496805829}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'preferred_skill_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'preferred_skill_score': 0.6496437986691794}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'preferred_skill_score': 0.6164550383885703}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'preferred_skill_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'preferred_skill_score': None}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'preferred_skill_score': 0.5932998259862265}, '23092c01-f933-4711-ac83-cbc310045763': {'preferred_skill_score': 0.6913315852483115}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'preferred_skill_score': 0.6857761343320212}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'preferred_skill_score': None}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'preferred_skill_score': 0.6419065694014233}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'preferred_skill_score': None}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'preferred_skill_score': None}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'preferred_skill_score': 0.5945247014363608}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'preferred_skill_score': 0.7840525706609092}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'preferred_skill_score': 0.8568442463874818}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'preferred_skill_score': 0.7365405327743955}, '44221648-dbaf-4b42-af68-0703ebb16835': {'preferred_skill_score': 0.9009393200729835}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'preferred_skill_score': 0.6868036190668744}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'preferred_skill_score': 0.8979115088780724}, '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'preferred_skill_score':  ...

# %% [markdown]
# ----
# #### Responsibilities Matching

# %%
from utils.responsibilities_match_score import calculate_responsibilities_scores

responsibilities_match_scores = calculate_responsibilities_scores(job_json_list=job_desc_json, resume_json=resume_json[7])
print(responsibilities_match_scores)
# Out:
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'responsibilities_score': 0.6304489033562799}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'responsibilities_score': 0.5818122070696621}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'responsibilities_score': 0.8091779373310232}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'responsibilities_score': 0.6812220322497098}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'responsibilities_score': 0.7094292442003889}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'responsibilities_score': 0.6397129013950443}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'responsibilities_score': 0.6924689035306031}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'responsibilities_score': 0.6674410634570653}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'responsibilities_score': 0.67803696791331}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'responsibilities_score': 0.6810111679412701}, '75a94499-c585-4181-b4de-09f1355a18a2': {'responsibilities_score': 0.6699562479579262}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'responsibilities_score': 0.6601205801813859}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'responsibilities_score': 0.6937121603460542}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'responsibilities_score': 0.5939985346738942}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'responsibilities_score': 0.6555389927493203}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'responsibilities_score': 0.6049178116493399}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'responsibilities_score': 0.6750988838849246}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'responsibilities_score': 0.6684479855355764}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'responsibilities_score': 0.7022121151288352}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'responsibilities_score': 0.6394514044125876}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'responsibilities_score': 0.6919052093117327}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'responsibilities_score': 0.6471661318231514}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'responsibilities_score': 0.6671588479736705}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'responsibilities_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'responsibilities_score': 0.6131791122375976}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'responsibilities_score': 0.6393586281273103}, 'ac212808-481d-4eba-a913-e04f86e660db': {'responsibilities_score': 0.6021057348008512}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'responsibilities_score': 0.5862254433605185}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'responsibilities_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'responsibilities_score': 0.6339511540200976}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'responsibilities_score': 0.679869247807397}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'responsibilities_score': 0.6302860644128588}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'responsibilities_score': 0.6064411912645614}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'responsibilities_score': 0.7084151125616499}, '23092c01-f933-4711-ac83-cbc310045763': {'responsibilities_score': 0.6572105635225386}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'responsibilities_score': None}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'responsibilities_score': 0.7659940520922346}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'responsibilities_score': 0.6837923851439623}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'responsibilities_score': 0.6250379513344987}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'responsibilities_score': 0.7527598560630502}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'responsibilities_score': 0.6097641209761304}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'responsibilities_score': 0.602650490308565}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'responsibilities_score': 0.6033289756566761}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'responsibilities_score': 0.6171210077073841}, '44221648-dbaf-4b42-af68-0703ebb16835': {'responsibilities_score': 0.740603051402352}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'responsibilities_score': 0.6931906631498627} ...

# %% [markdown]
# -----
# #### Education Matching

# %%
from utils.mandatory_education_score import calculate_mandatory_education_scores
from utils.preferred_education_score import calculate_preferred_education_scores

mandatory_education_scores = calculate_mandatory_education_scores(job_json_list=job_desc_json, resume_json=resume_json[7])
preferred_education_scores = calculate_preferred_education_scores(job_json_list=job_desc_json, resume_json=resume_json[7])

print(mandatory_education_scores)
print(preferred_education_scores)
# Out:
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': 0.0, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'mandatory_education_score': None}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'mandatory_education_score': 1.0}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'mandatory_education_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'mandatory_education_score': None}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': 0.0, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'mandatory_education_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': 0.0, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': 0.0, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'mandatory_education_score': None}, '75a94499-c585-4181-b4de-09f1355a18a2': 0.0, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': 0.0, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_education_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': 0.0, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_education_score': 1.0}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'mandatory_education_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': 0.0, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_education_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': 0.0, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_education_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'mandatory_education_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'mandatory_education_score': 1.0}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'mandatory_education_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_education_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': 0.0, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_education_score': 1.0}, 'ac212808-481d-4eba-a913-e04f86e660db': {'mandatory_education_score': None}, 'bb464343-964a-4eb5-851d-a7cc5753625e': 0.0, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'mandatory_education_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'mandatory_education_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': 0.0, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'mandatory_education_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': 0.0, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'mandatory_education_score': 1.0}, '23092c01-f933-4711-ac83-cbc310045763': {'mandatory_education_score': 1.0}, '3e3466a5-1799-4648-883d-ab43f1278a53': 0.0, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'mandatory_education_score': None}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'mandatory_education_score': None}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': 0.0, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': 0.0, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'mandatory_education_score': None}, 'ae020386-078f-4192-8ef4-089eaeb40125': 0.0, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': 0.0, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'mandatory_education_score': None}, '44221648-dbaf-4b42-af68-0703ebb16835': {'mandatory_education_score': None}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'mandatory_education_score': None}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': 0.0, '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'mandatory_education_score': None}, '7db57868-4db2-4be9-94fe-67574010017f': {'mandatory_education_score': None}, '90822d5e-c54f-49ad-a345-17a00f8b0c56': 0.0, 'c540dda2-7f78-4584-9a93-0d4c5ee2981b': {'mandatory_education_score': None}, '5e75d9a0-228b-463d-9025-f1b3ad048cf2': 0.0, '3aa02d0d-814b-4acc-ab15-06c897ebdec8': {'mandatory_education_score': None}, '7e8c1297-5fb7-4431-bfd0-ff76a071a24b': 0.0, '3d6abfd2-971f-4279-bd5c-e2608afb27b8': {'mandatory_education_score': None}, '1a8b8afd-5bf1-43a5-abb8-b533e7ba6fdc': {'mandatory_education_score': None}, '63f3d671-571d-4fcb-aa06-2200ea5d6313': {'mandatory_education_score': None}, 'f6ee0835-b07f-4ccf-8109-1d2c5b309061': {'mandatory_education_score': None}, 'd9a357a7-5e50-4bf8-a771-ef50414c2bac': {'mandatory_education_score': None}, 'c0ac98d7-dd65-4ab5-8d37-dfa26300f333': {'mandatory_education_score': None}, '158df241-dc50-4aff-86de-114acd3bd2e5': 0.0, 'c50cd8cd-60d1-48a7-8db8-7e828210c020': {'ma ...
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'preferred_education_score': 0.0}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'preferred_education_score': None}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'preferred_education_score': None}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'preferred_education_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'preferred_education_score': None}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'preferred_education_score': None}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'preferred_education_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'preferred_education_score': 0.0}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'preferred_education_score': None}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'preferred_education_score': None}, '75a94499-c585-4181-b4de-09f1355a18a2': {'preferred_education_score': 0.0}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'preferred_education_score': None}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'preferred_education_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'preferred_education_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'preferred_education_score': None}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'preferred_education_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'preferred_education_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'preferred_education_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'preferred_education_score': None}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'preferred_education_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'preferred_education_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'preferred_education_score': None}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'preferred_education_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'preferred_education_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'preferred_education_score': 0.0}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'preferred_education_score': None}, 'ac212808-481d-4eba-a913-e04f86e660db': {'preferred_education_score': None}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'preferred_education_score': None}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'preferred_education_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'preferred_education_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'preferred_education_score': None}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'preferred_education_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'preferred_education_score': 0.0}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'preferred_education_score': 1.0}, '23092c01-f933-4711-ac83-cbc310045763': {'preferred_education_score': 0.0}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'preferred_education_score': 0.0}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'preferred_education_score': None}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'preferred_education_score': None}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'preferred_education_score': None}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'preferred_education_score': 0.0}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'preferred_education_score': None}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'preferred_education_score': None}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'preferred_education_score': None}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'preferred_education_score': None}, '44221648-dbaf-4b42-af68-0703ebb16835': {'preferred_education_score': None}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'preferred_education_score': None}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'preferred_education_score': None}, '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'preferred_education_score': None}, '7db57868-4db2-4be9-94fe-67574010017f': {'preferred_education_score': None}, '90822d5e-c54f-49ad-a345-17a00f8b0c56': {'preferred_education_score': None}, 'c540dda2-7f78-4584-9a93-0d4c5ee2981b': {'preferred_education_score': None}, '5e75d9a0-228b-463d-9025-f1b3ad048cf2': {'preferred_education_score': 0.0}, '3aa0 ...

# %% [markdown]
# -----
# #### Credentials Matching

# %%
from utils.mandatory_credentials_score import calculate_mandatory_credentials_scores
from utils.preferred_credentials_score import calculate_preferred_credentials_scores

mandatory_credentials_scores = calculate_mandatory_credentials_scores(job_json_list=job_desc_json, resume_json=resume_json[7])
preferred_credentials_scores = calculate_preferred_credentials_scores(job_json_list=job_desc_json, resume_json=resume_json[7])

print(mandatory_credentials_scores)
print(preferred_credentials_scores)
# Out:
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'mandatory_credentials_score': None}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'mandatory_credentials_score': None}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'mandatory_credentials_score': 0.0}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'mandatory_credentials_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'mandatory_credentials_score': None}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'mandatory_credentials_score': None}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'mandatory_credentials_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'mandatory_credentials_score': None}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'mandatory_credentials_score': None}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'mandatory_credentials_score': 0.0}, '75a94499-c585-4181-b4de-09f1355a18a2': {'mandatory_credentials_score': None}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'mandatory_credentials_score': None}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_credentials_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'mandatory_credentials_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_credentials_score': None}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'mandatory_credentials_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'mandatory_credentials_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_credentials_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'mandatory_credentials_score': 0.0}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_credentials_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'mandatory_credentials_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'mandatory_credentials_score': 0.0}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'mandatory_credentials_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_credentials_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'mandatory_credentials_score': None}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_credentials_score': None}, 'ac212808-481d-4eba-a913-e04f86e660db': {'mandatory_credentials_score': None}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'mandatory_credentials_score': None}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'mandatory_credentials_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'mandatory_credentials_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'mandatory_credentials_score': None}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'mandatory_credentials_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'mandatory_credentials_score': 0.0}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'mandatory_credentials_score': None}, '23092c01-f933-4711-ac83-cbc310045763': {'mandatory_credentials_score': None}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'mandatory_credentials_score': None}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'mandatory_credentials_score': None}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'mandatory_credentials_score': None}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'mandatory_credentials_score': 0.0}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'mandatory_credentials_score': None}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'mandatory_credentials_score': None}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'mandatory_credentials_score': 0.0}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'mandatory_credentials_score': None}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'mandatory_credentials_score': None}, '44221648-dbaf-4b42-af68-0703ebb16835': {'mandatory_credentials_score': None}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'mandatory_credentials_score': None}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'mandatory_credentials_score': None}, '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'mandatory_credentials_score': None}, '7db57868-4db2-4be9-94fe-67574010017f': {'mandatory_credentials_score': None}, '90822d5e-c54f-49ad-a345-17a00f8b0c56': {'mandatory_credentials_score': None}, 'c540dda2-7f78-4584-9a93-0d4c5ee2981b': {'mandatory_cred ...
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'preferred_credentials_score': None}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'preferred_credentials_score': 0.0}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'preferred_credentials_score': None}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'preferred_credentials_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'preferred_credentials_score': None}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'preferred_credentials_score': None}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'preferred_credentials_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'preferred_credentials_score': None}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'preferred_credentials_score': 0.0}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'preferred_credentials_score': 0.0}, '75a94499-c585-4181-b4de-09f1355a18a2': {'preferred_credentials_score': None}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'preferred_credentials_score': 0.0}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'preferred_credentials_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'preferred_credentials_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'preferred_credentials_score': None}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'preferred_credentials_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'preferred_credentials_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'preferred_credentials_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'preferred_credentials_score': 0.0}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'preferred_credentials_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'preferred_credentials_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'preferred_credentials_score': None}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'preferred_credentials_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'preferred_credentials_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'preferred_credentials_score': None}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'preferred_credentials_score': None}, 'ac212808-481d-4eba-a913-e04f86e660db': {'preferred_credentials_score': None}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'preferred_credentials_score': None}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'preferred_credentials_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'preferred_credentials_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'preferred_credentials_score': None}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'preferred_credentials_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'preferred_credentials_score': None}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'preferred_credentials_score': None}, '23092c01-f933-4711-ac83-cbc310045763': {'preferred_credentials_score': None}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'preferred_credentials_score': None}, '560b033b-5ba3-43d7-a9f3-b62d81c290eb': {'preferred_credentials_score': 0.0}, '750c7271-ac87-4b39-a381-59a1f2bb07fc': {'preferred_credentials_score': 0.0}, 'b7a5df94-215b-465a-af5b-0a1c1a40d38e': {'preferred_credentials_score': None}, 'fdf5ddcf-6ea4-4c8c-a4aa-be278cf6f017': {'preferred_credentials_score': None}, '29cd66f5-7ab3-44a3-8633-29dfc9557a08': {'preferred_credentials_score': None}, 'ae020386-078f-4192-8ef4-089eaeb40125': {'preferred_credentials_score': 0.0}, '2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc': {'preferred_credentials_score': None}, '78802d2b-8437-4bbf-83ca-62f7166f3954': {'preferred_credentials_score': None}, '44221648-dbaf-4b42-af68-0703ebb16835': {'preferred_credentials_score': None}, 'c405dd8e-b2c5-436f-be66-bbf602c46f76': {'preferred_credentials_score': 0.0}, '28b3cec4-9cc9-4817-b133-181c8958cc3a': {'preferred_credentials_score': None}, '4016ff28-f2a9-4e9d-8ce8-4498679286a2': {'preferred_credentials_score': None}, '7db57868-4db2-4be9-94fe-67574010017f': {'preferred_credentials_score': 0.0}, '90822d5e-c54f-49ad-a345-17a00f8b0c56': {'preferred_credentials_score': 0.0}, 'c540dda2-7f78-4584-9a93-0d4c5ee2981b': {'preferred_credenti ...

# %% [markdown]
# -----
# #### Background Matching

# %%
from utils.mandatory_background_score import calculate_mandatory_background_scores
from utils.preferred_background_score import calculate_preferred_background_scores

mandatory_background_scores = calculate_mandatory_background_scores(job_json_list=job_desc_json, resume_json=resume_json[7])
preferred_background_scores = calculate_preferred_background_scores(job_json_list=job_desc_json, resume_json=resume_json[7])

print(mandatory_background_scores)
print(preferred_background_scores)
# Out:
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'mandatory_background_score': 0.0, 'mandatory_industry_score': 0.774607022603353}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'mandatory_background_score': 0.6403924739360811, 'mandatory_industry_score': None}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'mandatory_background_score': 0.0, 'mandatory_industry_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'mandatory_background_score': 0.6283577080567679, 'mandatory_industry_score': 0.0}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'mandatory_background_score': None, 'mandatory_industry_score': None}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'mandatory_background_score': 0.34746133198340745, 'mandatory_industry_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'mandatory_background_score': 1.0, 'mandatory_industry_score': None}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'mandatory_background_score': 1.0, 'mandatory_industry_score': 0.8166859149932864}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '75a94499-c585-4181-b4de-09f1355a18a2': {'mandatory_background_score': 0.2127544009023243, 'mandatory_industry_score': None}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'mandatory_background_score': 1.0, 'mandatory_industry_score': 0.0}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'mandatory_background_score': 0.0, 'mandatory_industry_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'mandatory_background_score': 0.6620153828461967, 'mandatory_industry_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'mandatory_background_score': 0.0, 'mandatory_industry_score': None}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_background_score': 0.6459024723370872, 'mandatory_industry_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'mandatory_background_score': 0.0, 'mandatory_industry_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_background_score': None, 'mandatory_industry_score': None}, 'ac212808-481d-4eba-a913-e04f86e660db': {'mandatory_background_score': 0.0, 'mandatory_industry_score': 0.0}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'mandatory_background_score': None, 'mandatory_industry_score': None}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'mandatory_background_score': None, 'mandatory_industry_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'mandatory_background_score': None, 'mandatory_industry_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'mandatory_background_score': 1.0, 'mandatory_industry_score': None}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'mandatory_background_score': None, 'mandatory_industry_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'mandatory_background_score': 0.0, 'mandatory_industry_score': 0.0}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'mandatory_background_score': 0.0, 'mandatory_industry_score': 0.6566085020701092}, '23092c01-f933-4711-ac83-cbc310045763': {'mandatory_background_score': 0.0, 'mand ...
# {'84b4a4d4-4fdb-45e8-bd40-c5679947f8b0': {'preferred_background_score': None, 'preferred_industry_score': None}, 'be46fbc9-8e00-4381-a545-9ed71b079a3a': {'preferred_background_score': None, 'preferred_industry_score': None}, '77773fdc-9c4e-4bdf-8e4a-2b82b08061b0': {'preferred_background_score': 0.6203949215014777, 'preferred_industry_score': None}, '1154d66d-c922-48ea-bb60-59c719b3c77d': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, 'cbbc9bbc-2f21-451f-ac20-01e4f2c611e1': {'preferred_background_score': None, 'preferred_industry_score': None}, '60111acc-73d9-4fe8-8a84-c826d9eeeca4': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, 'f0b34589-98f6-4b6a-a379-394e4e7f088f': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, 'e301b10c-7e2b-485e-8978-4ee2c9669953': {'preferred_background_score': None, 'preferred_industry_score': None}, 'f12ad9e6-0c44-4c19-8f5d-37c2f3f14c18': {'preferred_background_score': None, 'preferred_industry_score': None}, '9ff8b57c-9f01-448b-9ba9-d7d03b8db9dd': {'preferred_background_score': None, 'preferred_industry_score': None}, '75a94499-c585-4181-b4de-09f1355a18a2': {'preferred_background_score': None, 'preferred_industry_score': None}, 'd54b9f7b-d3ea-49b2-995c-c47d1a78576e': {'preferred_background_score': None, 'preferred_industry_score': None}, 'edcd8df0-7dc7-4896-8d28-c435462059b6': {'preferred_background_score': None, 'preferred_industry_score': None}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'preferred_background_score': None, 'preferred_industry_score': None}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'preferred_background_score': None, 'preferred_industry_score': None}, '8aa2b635-edbf-4901-bb3f-4d4f2c69e7fe': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'preferred_background_score': None, 'preferred_industry_score': None}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'preferred_background_score': None, 'preferred_industry_score': None}, '2510ddf5-282f-4f1c-bc72-44e34c8f67d8': {'preferred_background_score': None, 'preferred_industry_score': None}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'preferred_background_score': None, 'preferred_industry_score': None}, 'a25c98ff-be8f-4ea4-b740-e459455d16b8': {'preferred_background_score': None, 'preferred_industry_score': None}, '67cca7d7-0e75-49cf-9f27-4d6ec2bd7766': {'preferred_background_score': None, 'preferred_industry_score': None}, '0c9591b9-68aa-4d93-81a4-c090753a43d5': {'preferred_background_score': None, 'preferred_industry_score': None}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'preferred_background_score': None, 'preferred_industry_score': None}, '195f1df8-b444-4118-ad8f-b2d8a9959c34': {'preferred_background_score': None, 'preferred_industry_score': None}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'preferred_background_score': None, 'preferred_industry_score': None}, 'ac212808-481d-4eba-a913-e04f86e660db': {'preferred_background_score': 0.0, 'preferred_industry_score': 0.0}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'preferred_background_score': None, 'preferred_industry_score': None}, 'ac01e246-fa9b-4e5f-a7ed-fdd9cd1995b3': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, '9ccc15c2-060b-4fa5-8b88-4d8c2b65c251': {'preferred_background_score': None, 'preferred_industry_score': None}, 'fa055b06-313a-4ed6-88e9-282c1f073da3': {'preferred_background_score': 0.0, 'preferred_industry_score': None}, 'a19af6ea-09ff-4d3e-874e-88fe4ad2b8db': {'preferred_background_score': None, 'preferred_industry_score': None}, 'e92e6676-9a70-42b5-81d6-907782ebad16': {'preferred_background_score': None, 'preferred_industry_score': None}, '2bc7d30f-d8db-48e2-a76b-040ef73044a5': {'preferred_background_score': None, 'preferred_industry_score': None}, '23092c01-f933-4711-ac83-cbc310045763': {'preferred_background_score': None, 'preferred_industry_score': None}, '3e3466a5-1799-4648-883d-ab43f1278a53': {'preferred_background_score': No ...

# %% [markdown]
# ----

# %% [markdown]
# #### Merge Scores into One Object

# %%
from utils.merge_scores import merge_scores_by_job_id

final_scores = merge_scores_by_job_id(mandatory_background_scores, 
                                      preferred_background_scores, 
                                      mandatory_education_scores,
                                      preferred_education_scores,
                                      mandatory_skill_scores,
                                      preferred_skill_scores,
                                      mandatory_credentials_scores,
                                      preferred_credentials_scores,
                                      responsibilities_match_scores,
                                      filter = True,
                                      threshold= 0.5
                                      )  



print(final_scores)
# Out:
# {'edcd8df0-7dc7-4896-8d28-c435462059b6': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.7860985994338991, 'preferred_skill_score': None, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6937121603460542}, '2fd8af11-4583-4d06-822b-fad7c0c3bc9a': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.5150486760669285, 'preferred_skill_score': None, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.5939985346738942}, '8bd1bc07-2777-4c8e-89f8-7895e81b0abe': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': 1.0, 'preferred_education_score': None, 'mandatory_skill_score': 0.5533769428730012, 'preferred_skill_score': 0.6288245916366579, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6555389927493203}, '5cdf2c5a-05fa-40e7-b85b-cefccd795706': {'mandatory_background_score': 0.6620153828461967, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.8017839590708417, 'preferred_skill_score': None, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6750988838849246}, 'bb34a8a9-3de9-4707-ad05-9283e6bc44d2': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.5699568669001263, 'preferred_skill_score': 0.6919345404162554, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6684479855355764}, 'd8961472-c59c-48d1-a5b5-d49c778fcac5': {'mandatory_background_score': 0.6459024723370872, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.5648240923881531, 'preferred_skill_score': 0.5592267645729915, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6394514044125876}, 'bf9aa16e-181d-46fd-9b34-999b21221885': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.7202710034670654, 'preferred_skill_score': 0.7404390289669947, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': None}, '96051542-318e-4fd1-aea9-035cd9a74fe5': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'mandatory_education_score': 1.0, 'preferred_education_score': None, 'mandatory_skill_score': 0.7311100363731386, 'preferred_skill_score': 0.6998386912875708, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score': 0.6393586281273103}, 'bb464343-964a-4eb5-851d-a7cc5753625e': {'mandatory_background_score': None, 'mandatory_industry_score': None, 'preferred_background_score': None, 'preferred_industry_score': None, 'preferred_education_score': None, 'mandatory_skill_score': 0.5320566835857575, 'preferred_skill_score': 0.6203128496805829, 'mandatory_credentials_score': None, 'preferred_credentials_score': None, 'responsibilities_score ...

# %% [markdown]
# ----

# %% [markdown]
# #### Overall Scores

# %%
from utils.overall_scores import make_overall_scores

results = make_overall_scores(final_scores)

# %%
results
# Out:
# [('44221648-dbaf-4b42-af68-0703ebb16835',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': 1.0,
#    'preferred_industry_score': 0.7384345531463624,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.8346125748422413,
#    'preferred_skill_score': 0.9009393200729835,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.740603051402352,
#    'overall_mandatory': 0.7876078131222966,
#    'overall_preferred': 0.9504696600364917,
#    'overall_score': 0.8690387365793941,
#    'overall_skills': 0.8677759474576123,
#    'overall_education': None,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('08d80a05-d86e-4fbf-9203-502dfad0f0f2',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': 1.0,
#    'preferred_industry_score': 0.9642459551493329,
#    'mandatory_education_score': None,
#    'preferred_education_score': 1.0,
#    'mandatory_skill_score': 0.7614532113075259,
#    'preferred_skill_score': 0.7102872530619305,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.7100640336672466,
#    'overall_mandatory': 0.7357586224873863,
#    'overall_preferred': 0.9034290843539766,
#    'overall_score': 0.8195938534206815,
#    'overall_skills': 0.7358702321847281,
#    'overall_education': 1.0,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('2ce38b1b-2ff5-44f3-b8af-45dbd5e8c4fc',
#   {'mandatory_background_score': 1.0,
#    'mandatory_industry_score': 0.7411711506545544,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6981486678123475,
#    'preferred_skill_score': 0.8568442463874818,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6033289756566761,
#    'overall_mandatory': 0.7671592144896745,
#    'overall_preferred': 0.8568442463874818,
#    'overall_score': 0.8120017304385782,
#    'overall_skills': 0.7774964570999147,
#    'overall_education': None,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('28b3cec4-9cc9-4817-b133-181c8958cc3a',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7886572010589369,
#    'preferred_skill_score': 0.8979115088780724,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6612840497659315,
#    'overall_mandatory': 0.7249706254124342,
#    'overall_preferred': 0.8979115088780724,
#    'overall_score': 0.8114410671452532,
#    'overall_skills': 0.8432843549685046,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('3d6abfd2-971f-4279-bd5c-e2608afb27b8',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7870239118734997,
#    'preferred_skill_score': 0.90708793203036,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6081759383281073,
#    'overall_mandatory': 0.6975999251008036,
#    'overall_preferred': 0.90708793203036,
#    'overall_score': 0.8023439285655818,
#    'overall_skills': 0.8470559219519298,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('71bb20b6-57a4-40e3-b3bd-13b052ef904b',
#   {'mandatory_background_score': 0.6494102612137795,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.8793958293067087,
#    'preferred_skill_score': 0.8473974068959556,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.7092794378598533,
#    'overall_mandatory': 0.7460285094601138,
#    'overall_preferred': 0.8473974068959556,
#    'overall_score': 0.7967129581780347,
#    'overall_skills': 0.8633966181013322,
#    'overall_education': None,
#    'overall_background': 0.6494102612137795,
#    'overall_credentials': None}),
#  ('137098ec-6b03-47cc-adcc-4f2d672a20f9',
#   {'mandatory_background_score': 1.0,
#    'mandatory_industry_score': None,
#    'preferred_background_score': 0.6739209002342779,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.8313801873613288,
#    'preferred_skill_score': 0.8383761445681255,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6393030881881715,
#    'overall_mandatory': 0.8235610918498334,
#    'overall_preferred': 0.7561485224012017,
#    'overall_score': 0.7898548071255176,
#    'overall_skills': 0.8348781659647271,
#    'overall_education': None,
#    'overall_background': 0.8369604501171389,
#    'overall_credentials': None}),
#  ('f6ee0835-b07f-4ccf-8109-1d2c5b309061',
#   {'mandatory_background_score': 1.0,
#    'mandatory_industry_score': None,
#    'preferred_background_score': 1.0,
#    'preferred_industry_score': 0.7411711506545544,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.752573853447324,
#    'preferred_skill_score': 0.5483664671579999,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6534273673039475,
#    'overall_mandatory': 0.8020004069170904,
#    'overall_preferred': 0.774183233579,
#    'overall_score': 0.7880918202480451,
#    'overall_skills': 0.6504701603026619,
#    'overall_education': None,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('794dda95-c86e-4575-90dd-6d5fe9b34268',
#   {'mandatory_background_score': 1.0,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': 1.0,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5728392402331036,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.579051368766361,
#    'overall_mandatory': 0.7879726522498661,
#    'overall_preferred': None,
#    'overall_score': 0.7879726522498661,
#    'overall_skills': 0.5728392402331036,
#    'overall_education': 1.0,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('53acdd0a-467a-413e-9486-42a2b86b5c66',
#   {'mandatory_background_score': 1.0,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6753267447153729,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6498084763685863,
#    'overall_mandatory': 0.775045073694653,
#    'overall_preferred': None,
#    'overall_score': 0.775045073694653,
#    'overall_skills': 0.6753267447153729,
#    'overall_education': None,
#    'overall_background': 1.0,
#    'overall_credentials': None}),
#  ('181b9a3d-71ca-420e-8ea8-08b348ad69f2',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7771745125452679,
#    'preferred_skill_score': 0.7967961513333851,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6897816941851662,
#    'overall_mandatory': 0.7334781033652171,
#    'overall_preferred': 0.7967961513333851,
#    'overall_score': 0.7651371273493011,
#    'overall_skills': 0.7869853319393265,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('a7df6bed-41c2-4ccd-a3a1-d0bfb90adf5e',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6798191302352483,
#    'preferred_skill_score': 0.8698782920837405,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6124753485123319,
#    'overall_mandatory': 0.6461472393737901,
#    'overall_preferred': 0.8698782920837406,
#    'overall_score': 0.7580127657287654,
#    'overall_skills': 0.7748487111594944,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('96051542-318e-4fd1-aea9-035cd9a74fe5',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': 1.0,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7311100363731386,
#    'preferred_skill_score': 0.6998386912875708,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6393586281273103,
#    'overall_mandatory': 0.7901562215001495,
#    'overall_preferred': 0.6998386912875707,
#    'overall_score': 0.7449974563938602,
#    'overall_skills': 0.7154743638303547,
#    'overall_education': 1.0,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('65ad643c-f389-494e-aaba-210e41917b8d',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7302761122032448,
#    'preferred_skill_score': 0.7738785048325859,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6934828493330215,
#    'overall_mandatory': 0.7118794807681331,
#    'overall_preferred': 0.7738785048325859,
#    'overall_score': 0.7428789928003595,
#    'overall_skills': 0.7520773085179153,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('edcd8df0-7dc7-4896-8d28-c435462059b6',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7860985994338991,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6937121603460542,
#    'overall_mandatory': 0.7399053798899768,
#    'overall_preferred': None,
#    'overall_score': 0.7399053798899768,
#    'overall_skills': 0.7860985994338991,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('bf9aa16e-181d-46fd-9b34-999b21221885',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7202710034670654,
#    'preferred_skill_score': 0.7404390289669947,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': None,
#    'overall_mandatory': 0.7202710034670654,
#    'overall_preferred': 0.7404390289669947,
#    'overall_score': 0.73035501621703,
#    'overall_skills': 0.73035501621703,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('4016ff28-f2a9-4e9d-8ce8-4498679286a2',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.834770891401503,
#    'preferred_skill_score': 0.6850101153055829,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.656618645897618,
#    'overall_mandatory': 0.7456947686495604,
#    'overall_preferred': 0.6850101153055829,
#    'overall_score': 0.7153524419775716,
#    'overall_skills': 0.7598905033535429,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('5cdf2c5a-05fa-40e7-b85b-cefccd795706',
#   {'mandatory_background_score': 0.6620153828461967,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.8017839590708417,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6750988838849246,
#    'overall_mandatory': 0.7129660752673208,
#    'overall_preferred': None,
#    'overall_score': 0.7129660752673208,
#    'overall_skills': 0.8017839590708417,
#    'overall_education': None,
#    'overall_background': 0.6620153828461967,
#    'overall_credentials': None}),
#  ('137510b3-5847-44c2-a16a-61558634845a',
#   {'mandatory_background_score': 0.6371979894240699,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5792107222572208,
#    'preferred_skill_score': 0.7911612192789715,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6339579226951751,
#    'overall_mandatory': 0.6167888781254885,
#    'overall_preferred': 0.7911612192789715,
#    'overall_score': 0.70397504870223,
#    'overall_skills': 0.6851859707680962,
#    'overall_education': None,
#    'overall_background': 0.6371979894240699,
#    'overall_credentials': None}),
#  ('c540dda2-7f78-4584-9a93-0d4c5ee2981b',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6941530414753492,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': None,
#    'overall_mandatory': 0.6941530414753492,
#    'overall_preferred': None,
#    'overall_score': 0.6941530414753492,
#    'overall_skills': 0.6941530414753492,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('639fb093-26a8-4745-9656-ee93f3b79f19',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7201358775297804,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6672919591267906,
#    'overall_mandatory': 0.6937139183282856,
#    'overall_preferred': None,
#    'overall_score': 0.6937139183282856,
#    'overall_skills': 0.7201358775297804,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('8bd1bc07-2777-4c8e-89f8-7895e81b0abe',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': 1.0,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5533769428730012,
#    'preferred_skill_score': 0.6288245916366579,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6555389927493203,
#    'overall_mandatory': 0.7363053118741071,
#    'overall_preferred': 0.6288245916366578,
#    'overall_score': 0.6825649517553825,
#    'overall_skills': 0.5911007672548296,
#    'overall_education': 1.0,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('9ccc15c2-060b-4fa5-8b88-4d8c2b65c251',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.7703759496410689,
#    'preferred_skill_score': 0.6496437986691794,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6339511540200976,
#    'overall_mandatory': 0.7021635518305832,
#    'overall_preferred': 0.6496437986691794,
#    'overall_score': 0.6759036752498813,
#    'overall_skills': 0.7100098741551242,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('7e8c1297-5fb7-4431-bfd0-ff76a071a24b',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6035568267107011,
#    'preferred_skill_score': 0.7165962060292564,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.657078837906873,
#    'overall_mandatory': 0.6303178323087871,
#    'overall_preferred': 0.7165962060292564,
#    'overall_score': 0.6734570191690218,
#    'overall_skills': 0.6600765163699788,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('3aa02d0d-814b-4acc-ab15-06c897ebdec8',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.58663480480512,
#    'preferred_skill_score': 0.7240354617436728,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6261314245370719,
#    'overall_mandatory': 0.606383114671096,
#    'overall_preferred': 0.7240354617436728,
#    'overall_score': 0.6652092882073843,
#    'overall_skills': 0.6553351332743964,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('bb34a8a9-3de9-4707-ad05-9283e6bc44d2',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5699568669001263,
#    'preferred_skill_score': 0.6919345404162554,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6684479855355764,
#    'overall_mandatory': 0.6192024262178514,
#    'overall_preferred': 0.6919345404162554,
#    'overall_score': 0.6555684833170534,
#    'overall_skills': 0.6309457036581908,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('18df64e2-17f0-45b0-8759-ba1b89fad7dd',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6155027548472088,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6208681559857029,
#    'overall_mandatory': 0.6181854554164559,
#    'overall_preferred': None,
#    'overall_score': 0.6181854554164559,
#    'overall_skills': 0.6155027548472088,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('c50cd8cd-60d1-48a7-8db8-7e828210c020',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.6032019456227622,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.5858420259021351,
#    'overall_mandatory': 0.5945219857624486,
#    'overall_preferred': None,
#    'overall_score': 0.5945219857624486,
#    'overall_skills': 0.6032019456227622,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('2b2477c7-fafb-411f-b890-11cbb24d02e0',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5933388948440553,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': None,
#    'overall_mandatory': 0.5933388948440553,
#    'overall_preferred': None,
#    'overall_score': 0.5933388948440553,
#    'overall_skills': 0.5933388948440553,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('bb464343-964a-4eb5-851d-a7cc5753625e',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5320566835857575,
#    'preferred_skill_score': 0.6203128496805829,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.5862254433605185,
#    'overall_mandatory': 0.5591410634731381,
#    'overall_preferred': 0.6203128496805829,
#    'overall_score': 0.5897269565768605,
#    'overall_skills': 0.5761847666331702,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None}),
#  ('d8961472-c59c-48d1-a5b5-d49c778fcac5',
#   {'mandatory_background_score': 0.6459024723370872,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'mandatory_education_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5648240923881531,
#    'preferred_skill_score': 0.5592267645729915,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.6394514044125876,
#    'overall_mandatory': 0.6167259897126092,
#    'overall_preferred': 0.5592267645729915,
#    'overall_score': 0.5879763771428004,
#    'overall_skills': 0.5620254284805724,
#    'overall_education': None,
#    'overall_background': 0.6459024723370872,
#    'overall_credentials': None}),
#  ('2fd8af11-4583-4d06-822b-fad7c0c3bc9a',
#   {'mandatory_background_score': None,
#    'mandatory_industry_score': None,
#    'preferred_background_score': None,
#    'preferred_industry_score': None,
#    'preferred_education_score': None,
#    'mandatory_skill_score': 0.5150486760669285,
#    'preferred_skill_score': None,
#    'mandatory_credentials_score': None,
#    'preferred_credentials_score': None,
#    'responsibilities_score': 0.5939985346738942,
#    'overall_mandatory': 0.5545236053704113,
#    'overall_preferred': None,
#    'overall_score': 0.5545236053704113,
#    'overall_skills': 0.5150486760669285,
#    'overall_education': None,
#    'overall_background': None,
#    'overall_credentials': None})]

# %%
len(final_scores)
# Out:
# 32

# %% [markdown]
# #### Eval

# %%
matched_jobids = [job_id for job_id, _ in results]

filtered_jobs = [
    j for j in job_desc_json
    if j.get("job_id") in matched_jobids
]

# %%
# Loop through all backgrounds in job_desc_json and print 
for job in job_desc_json:
    job_id = job.get("job_id")
    print(f"Job ID: {job_id}")

    # 1) Mandatory professional backgrounds
    mandatory_bgs = job.get("mandatory", {}).get("professional_background", [])
    for i, bg_req in enumerate(mandatory_bgs, start=1):
        print(f"  Mandatory Background #{i}: {bg_req}")

    # 2) Preferred professional backgrounds
    preferred_bgs = job.get("preferred", {}).get("professional_background", [])
    for i, bg_req in enumerate(preferred_bgs, start=1):
        print(f"  Preferred Background #{i}: {bg_req}")
# Out:
# Job ID: cc807c45-4a2f-4335-90d5-b50669459cc5
#   Mandatory Background #1: {'industry': [], 'minyears': [8], 'background': [['Oracle Cloud ERP']]}
# Job ID: 1400a854-77d4-4aab-a84c-9a643f100657
#   Mandatory Background #1: {'industry': [], 'minyears': [8], 'background': [['relevant engineering hands-on work']]}
# Job ID: 72f7a93e-824e-485f-b356-58c523fe65d0
#   Mandatory Background #1: {'industry': ['financial services'], 'minyears': [5], 'background': [['Marketing Analytics'], ['similar practical experience']]}
#   Preferred Background #1: {'industry': ['financial services', 'mortgage', 'credit card', 'personal loans', 'business loans'], 'minyears': [0], 'background': [['Marketing Analytics'], ['similar practical experience']]}
# Job ID: ba72461b-56f5-4c1b-90b0-3c3b9ffa8a1c
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [["Bachelor's degree", 'computer science'], ['Software Engineering']]}
#   Mandatory Background #2: {'industry': [], 'minyears': [0], 'background': [['3rd party digital e-commerce platform experience'], ['IBM Sterling OMS'], ['Radial OMS'], ['Salesforce Commerce Cloud', 'SFCC']]}
#   Mandatory Background #3: {'industry': [], 'minyears': [0], 'background': [['best practices'], ['IT operations', 'always-up', 'always-available mission-critical service']]}
# Job ID: a713d178-a7dc-4f03-b569-9c7deb76bff3
# Job ID: 428eda01-4bb2-44c7-9281-9a5c43f92e3a
#   Mandatory Background #1: {'industry': [], 'minyears': [3], 'background': [['Work Experience']]}
# Job ID: 5c89be22-d4da-483f-815a-fbc31e6e14dd
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['managing mid-sized migration projects']]}
# Job ID: 8312a3ee-11fa-48a0-946a-a24ad3dc4e7e
# Job ID: f7842b4d-9109-4ce1-b506-d36989207b87
#   Mandatory Background #1: {'industry': [], 'minyears': [3], 'background': [['information security'], ['risk management']]}
# Job ID: c8c0c00a-4efd-4b02-b681-fa7d6280d827
#   Preferred Background #1: {'industry': [], 'minyears': [0], 'background': [['accounting'], ['financial systems']]}
# Job ID: 63af5a5c-5d46-4c8d-b778-ffa195ab4fac
# Job ID: 91ff5695-564e-4e0c-aad2-f244ab0ed707
#   Mandatory Background #1: {'industry': ['data analytics', 'performance management system', 'data warehousing'], 'minyears': [8], 'background': [['system analyst']]}
#   Preferred Background #1: {'industry': ['Healthcare'], 'minyears': [0], 'background': [['Work Experience']]}
#   Preferred Background #2: {'industry': ['HHS'], 'minyears': [0], 'background': [['Work Experience']]}
#   Preferred Background #3: {'industry': [], 'minyears': [0], 'background': [['PII data'], ['PHI data']]}
# Job ID: abf21387-accd-4314-8f2b-eb03a8de6483
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['Solution Architect'], ['similar role']]}
#   Preferred Background #1: {'industry': [], 'minyears': [0], 'background': [['enterprise architecture principles'], ['frameworks']]}
# Job ID: 11fb3b10-360e-4d3f-9048-443356ae0dcd
# Job ID: 446eb377-d4b8-4362-8a9f-3c5bc27e9a1e
#   Mandatory Background #1: {'industry': [], 'minyears': [2], 'background': [['Work Experience']]}
# Job ID: dbf6ef88-8fc8-48d8-8d3b-1887e8ecadf2
# Job ID: 2caf9581-cb9c-447f-b2c0-fe5c00079a12
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['engineer']]}
# Job ID: 6d9427ef-f3f3-4775-970e-47d0fab27232
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['quality'], ['failure analysis'], ['semiconductor assembly'], ['packaging']]}
#   Preferred Background #1: {'industry': [], 'minyears': [7], 'background': [['microelectronics packaging quality'], ['reliability']]}
# Job ID: 5e27c0e2-98e7-418b-b06d-34dc3cd6fabf
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['networking'], ['infrastructure'], ['database engineering'], ['operations']]}
# Job ID: 3ae7dbbf-4b5a-4b81-8d7a-a277053712a8
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['DevOps Engineer'], ['software engineering role']]}
# Job ID: aa54e1d3-45ef-49c5-82cf-b458266999bf
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['Software Engineering'], ['Work Experience']]}
# Job ID: 2fdfca8c-8cc8-47f1-8fc4-69e1df80499a
#   Mandatory Background #1: {'industry': ['financial services'], 'minyears': [0], 'background': [['financial services industry']]}
# Job ID: 4d839fa4-e2a0-40fb-9e7e-b6900e969b1b
#   Mandatory Background #1: {'industry': ['Information Technology'], 'minyears': [10], 'background': [['Work Experience']]}
# Job ID: e86a1038-ad25-4e9f-a763-681e9d42cc54
#   Mandatory Background #1: {'industry': [], 'minyears': [3], 'background': [['business analysis']]}
# Job ID: 44d1ece1-c659-4023-8242-71b16b7f3a4d
# Job ID: 3f21690a-eaf2-4df0-b39d-616396805a84
#   Mandatory Background #1: {'industry': [], 'minyears': [2], 'background': [['knowledge management'], ['content analysis'], ['content management'], ['Work Experience']]}
# Job ID: ce1feeeb-e558-4e01-9e97-ab177c9ea543
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['Support projects']]}
# Job ID: ae1d4bb2-5499-46e0-9949-6b9136123c3e
# Job ID: 3a70b547-a8e2-4f09-b783-025921917826
#   Mandatory Background #1: {'industry': [], 'minyears': [4], 'background': [['design of electric utility transmission systems']]}
#   Preferred Background #1: {'industry': [], 'minyears': [8], 'background': [['design of electric utility transmission systems']]}
# Job ID: 6c90680b-4173-49cd-9b79-6e642dffd363
# Job ID: cd2b1168-812d-407c-8ea9-ea6589202bf0
#   Mandatory Background #1: {'industry': [], 'minyears': [7], 'background': [['IT work experience', 'infrastructure/systems environments', 'systems planning', 'architecture design', 'engineering', 'hardware', 'software', 'optimization']]}
#   Mandatory Background #2: {'industry': [], 'minyears': [3], 'background': [['IT work experience', 'infrastructure/network environments', 'systems operations', 'support', 'maintenance', 'administration']]}
# Job ID: a66264a5-a5f5-465b-8798-09a42dd71bb0
# Job ID: 7d99b68a-bc35-4585-bb62-81cfe19bcfb4
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['software engineering concepts']]}
# Job ID: 99d1d8cf-fd25-49b9-a966-0648b14e7877
#   Mandatory Background #1: {'industry': [], 'minyears': [10], 'background': [['Work Experience']]}
# Job ID: 606e4e0a-d5e0-456a-9c54-76925e5f380e
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['developer']]}
#   Preferred Background #1: {'industry': [], 'minyears': [0], 'background': [['scrum environment']]}
# Job ID: 76133e6a-0bb2-4ab8-bb5c-a93aa7560be5
# Job ID: f3c29df1-89f3-4e3a-8727-227a566039ab
# Job ID: 8fa73939-f743-4fa2-869f-7f1f42ed30d4
#   Mandatory Background #1: {'industry': [], 'minyears': [15], 'background': [['SAP Sales'], ['Distribution'], ['Logistics']]}
#   Preferred Background #1: {'industry': [], 'minyears': [0], 'background': [['implementing SAP S/4'], ['working', 'production support']]}
# Job ID: fee842f2-241e-4ef2-9d32-42d3bc66cf49
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['Food Company Experience', 'Quality'], ['Food Company Experience', 'Food Safety'], ['Food Company Experience', 'Plant Operations']]}
#   Mandatory Background #2: {'industry': [], 'minyears': [0], 'background': [['Managing multiple projects'], ['creating and fostering strong business relationships']]}
#   Preferred Background #1: {'industry': [], 'minyears': [3], 'background': [['Food Company Experience', 'Quality'], ['Food Company Experience', 'Food Safety'], ['Food Company Experience', 'Plant Operations']]}
# Job ID: a4c9022f-5c50-4625-98e0-5d420dca3c51
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['functional consultant']]}
# Job ID: 3ba7b68c-b141-43b4-801d-d49ef8ade8d0
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['NASA Information Technology Leadership']]}
#   Mandatory Background #2: {'industry': [], 'minyears': [0], 'background': [['manage technical and administrative contract requirements']]}
#   Mandatory Background #3: {'industry': [], 'minyears': [0], 'background': [['team organization']]}
#   Mandatory Background #4: {'industry': [], 'minyears': [0], 'background': [['resource prioritization']]}
#   Mandatory Background #5: {'industry': [], 'minyears': [0], 'background': [['mentoring']]}
# Job ID: 2c7ab503-8dac-42f0-a919-79d507d5f680
#   Mandatory Background #1: {'industry': [], 'minyears': [1], 'background': [['Work Experience']]}
# Job ID: 33606f21-c4ac-475c-acbb-a36e98ec87e4
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['Azure cloud environments']]}
#   Preferred Background #1: {'industry': [], 'minyears': [0], 'background': [['Mentor team members', 'data principles'], ['Mentor team members', 'patterns'], ['Mentor team members', 'processes'], ['Mentor team members', 'practices']]}
# Job ID: 0a105d65-2ac3-4968-b05b-4663ac40eb08
# Job ID: 8f18c70a-4a3b-4089-bcfa-1db5575498fa
#   Mandatory Background #1: {'industry': [], 'minyears': [0], 'background': [['Full stack developer']]}
# Job ID: 386647de-9b0d-4c3c-9e7d-778d0a78c8db
#   Mandatory Background #1: {'industry': ['Retail', 'sales', 'service'], 'minyears': [0], 'background': [['business needs'], ['blending them'], ['package-based solutions'], ['meet all the variety of IT needs']]}
# Job ID: 2881083c-57f2-45eb-8cd2-db242686082b
#   Mandatory Background #1: {'industry': ['manufacturing'], 'minyears': [5], 'background': [['quality assurance']]}
# Job ID: 374d36b0-fac6-4a02-aff8-96a962e630e6
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['system administrator role']]}
# Job ID: 618c72af-4d4d-41f8-99a3-9c5d0abfc0b8
#   Mandatory Background #1: {'industry': [], 'minyears': [12], 'background': [['Work Experience']]}
# Job ID: ac563c72-1df3-4929-8b68-35b6a1770dd3
#   Mandatory Background #1: {'industry': [], 'minyears': [5], 'background': [['Work Experience']]}
#   Preferred Background #1: {'industry': [], 'minyears': [3], 'background': [['Work Experience']]}
